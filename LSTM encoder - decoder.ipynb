# %%
import gensim
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import pairwise_distances, silhouette_score
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
import networkx as nx
from node2vec import Node2Vec
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
from tqdm.notebook import tqdm
import re
import nltk
import pickle
from termcolor import colored
import swifter
from random import randint

# %%
normalize([[10,10]])
# Out:
# array([[0.70710678, 0.70710678]])

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Conv1D, MaxPool1D, AveragePooling1D, Flatten, UpSampling1D, Dense, Bidirectional, Dropout, Reshape
# Out:
# Using TensorFlow backend.

# %%
model = gensim.models.KeyedVectors.load('araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model')

# %%
dramas = [f for f in listdir('drama/') if isfile(join('drama/', f))]
dramas_texts = []


for drama in dramas:
    with open(join('drama/', drama), 'rb') as f:
        dramas_texts.append(pickle.load(f))

dramas_texts[0][0][:5]
# Out:
# [('Григорий', 'Ступай отвори дверь! звонят!'),
#  ('Петр',
#   'Да ты что сидишь? На ногах у тебя пузыри, что ли? встать не можешь?'),
#  ('Иван', 'Ну, уж я пойду, так и быть, отворю! Это Андрюшка!'),
#  ('Григорий', 'А, московская ворона! Откуда тебя принесло?'),
#  ('Чужой слуга',
#   'Ах ты, чухонский сын! Побегал бы ты с мое. Вот к цветочнице велела снесть, что на Петербургской. Небось четвертака на извозчика не\n            даст. Да и к вашему тож. Что, спит?')]

# %%
only_sents = []

for drama in tqdm(dramas_texts):
    for part in drama:
        only_sents = only_sents + [sent for _, sent in part]
        
only_sents = [sent for sent in only_sents if len(nltk.word_tokenize(sent))>0]    
only_sents[:5]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=210.0), HTML(value='')))
# ['Ступай отвори дверь! звонят!',
#  'Да ты что сидишь? На ногах у тебя пузыри, что ли? встать не можешь?',
#  'Ну, уж я пойду, так и быть, отворю! Это Андрюшка!',
#  'А, московская ворона! Откуда тебя принесло?',
#  'Ах ты, чухонский сын! Побегал бы ты с мое. Вот к цветочнице велела снесть, что на Петербургской. Небось четвертака на извозчика не\n            даст. Да и к вашему тож. Что, спит?']

# %%
def my_pad(vectors, max_size=50):
    vec_size=len(vectors[0])
    pad_size = max(0, max_size - len(vectors))
    return [vec[:vec_size] for vec in np.pad(vectors, (0, pad_size), mode='mean')][:max_size]

# %%
X = np.array([my_pad([model.get_vector(word) for word in nltk.word_tokenize(sent)], 50) for sent in tqdm(only_sents)])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=117273.0), HTML(value='')))

# %%
X[0]
# Out:
# array([[ 0.00705226, -0.00088858,  0.00459899, ...,  0.00549109,
#          0.00406344,  0.00493256],
#        [-0.02272115, -0.00689367,  0.01350532, ..., -0.01976017,
#          0.0004971 , -0.0040591 ],
#        [-0.09457409,  0.05680228,  0.02550063, ..., -0.01518658,
#          0.09124126, -0.01849104],
#        ...,
#        [-0.01895454,  0.00710081,  0.00507829, ..., -0.00464066,
#          0.02097317, -0.0072009 ],
#        [-0.01895454,  0.00710081,  0.00507829, ..., -0.00464066,
#          0.02097317, -0.0072009 ],
#        [-0.01895454,  0.00710081,  0.00507829, ..., -0.00464066,
#          0.02097317, -0.0072009 ]], dtype=float32)

# %%
encoder_decoder = Sequential()
encoder_decoder.add(Conv1D(100, 5, activation='tanh', input_shape=(50, 300)))
encoder_decoder.add(AveragePooling1D(2))
encoder_decoder.add(Conv1D(100, 5, activation='relu'))
encoder_decoder.add(MaxPool1D(2))
encoder_decoder.add(Conv1D(10, 5))
encoder_decoder.add(Flatten())
encoder_decoder.add(Dropout(0.25))
encoder_decoder.add(Dense(100, activation='tanh')) #encoded
encoder_decoder.add(Dense(500, activation='relu'))
encoder_decoder.add(Reshape((50, 10)))
encoder_decoder.add(Conv1D(300, 1, strides=1, padding='same'))
encoder_decoder.compile(loss="cosine_proximity", optimizer='adam', metrics=['mape', 'mae'])

encoder_decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_102 (Conv1D)          (None, 46, 100)           150100
# _________________________________________________________________
# average_pooling1d_32 (Averag (None, 23, 100)           0
# _________________________________________________________________
# conv1d_103 (Conv1D)          (None, 19, 100)           50100
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 9, 100)            0
# _________________________________________________________________
# conv1d_104 (Conv1D)          (None, 5, 10)             5010
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 50)                0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 100)               5100
# _________________________________________________________________
# dense_50 (Dense)             (None, 500)               50500
# _________________________________________________________________
# reshape_23 (Reshape)         (None, 50, 10)            0
# _________________________________________________________________
# conv1d_105 (Conv1D)          (None, 50, 300)           3300
# =================================================================
# Total params: 264,110
# Trainable params: 264,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
for _ in range(50):
    sent_num = randint(0, len(X))
    a = encoder_decoder.predict(np.array([X[sent_num]]))[0]
    print(only_sents[sent_num])
    out = [model.wv.most_similar(positive=[normalize([vec])[0],])[0][0] for vec in a]
    print(' '.join(out))
    encoder_decoder.fit(X, X, validation_split=0.2, batch_size=128, epochs=1)
# Out:
# Неужели?..
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# очем очем очем очем очем очем думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать думать
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   256/93818 [..............................] - ETA: 1:01 - loss: -0.4208 - mean_absolute_percentage_error: 935.1409 - mean_absolute_error: 0.0110
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 66s 704us/step - loss: -0.4711 - mean_absolute_percentage_error: 824.6360 - mean_absolute_error: 0.0105 - val_loss: -0.4955 - val_mean_absolute_percentage_error: 852.5281 - val_mean_absolute_error: 0.0106
# Батюшка не жалует, чтоб в его доме занимались вестьми городовыми, некасательными до
#               нас.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# дак дуче хотец по-твоему хото хото хотей каламата гаэта маиор хотей хотец хотей дуче хотец хотец хотец хотец людь людь людь людь людь людь людь быхом людь людь людь людь людь людь людь людь людь людь людь быхом людь быхом быхом быхом быхом быхом быхом быхом быхом быхом быхом быхом
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   128/93818 [..............................] - ETA: 1:12 - loss: -0.4990 - mean_absolute_percentage_error: 911.7644 - mean_absolute_error: 0.0110
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 71s 759us/step - loss: -0.4955 - mean_absolute_percentage_error: 936.7178 - mean_absolute_error: 0.0111 - val_loss: -0.5041 - val_mean_absolute_percentage_error: 980.9101 - val_mean_absolute_error: 0.0114
# Вот, братец ты мой, возьми домой, перепиши это почище. Приказали.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# дак дак лаша лаша куим куим батя батя батя дак дак дак кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха кирюха
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   128/93818 [..............................] - ETA: 1:31 - loss: -0.4910 - mean_absolute_percentage_error: 1082.9164 - mean_absolute_error: 0.0118
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 82s 869us/step - loss: -0.5011 - mean_absolute_percentage_error: 1056.9345 - mean_absolute_error: 0.0119 - val_loss: -0.5068 - val_mean_absolute_percentage_error: 1082.4956 - val_mean_absolute_error: 0.0120
# Что вы, Антон Игнатьич, как же я смею про бога знать? Про бога никто не смеет знать,
#               не было еще такой головы отчаянной. Не принести вам чайку, Антон Игнатьич? С
#               молочком?
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# хотец ари неужто шутя неужто неужто дак неужто беф невежа неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто неужто
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   256/93818 [..............................] - ETA: 1:05 - loss: -0.5076 - mean_absolute_percentage_error: 1384.5096 - mean_absolute_error: 0.0116
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 73s 776us/step - loss: -0.5031 - mean_absolute_percentage_error: 1169.3001 - mean_absolute_error: 0.0126 - val_loss: -0.5100 - val_mean_absolute_percentage_error: 1185.3949 - val_mean_absolute_error: 0.0129
# Так с Пронским не решили?
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# муда муда нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец нец
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   128/93818 [..............................] - ETA: 1:21 - loss: -0.5054 - mean_absolute_percentage_error: 1436.0500 - mean_absolute_error: 0.0135
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 73s 782us/step - loss: -0.5048 - mean_absolute_percentage_error: 1273.6283 - mean_absolute_error: 0.0134 - val_loss: -0.5134 - val_mean_absolute_percentage_error: 1254.1499 - val_mean_absolute_error: 0.0134
# Левый шинкель приложи и направо поверни!
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# ...
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# кирюха дио дуче мадмуазель ариг хотец дуче хотец аудиотека понь шеша диоскуры шак арь танаис якша вела якша людь дуче дуче гомер чеж шеша шеша лала сией мадмуазель шеша сией сией шеша сией сией шеша сией шеша вела шеша шеша шеша шеша шеша быхом шеша шеша шеша шеша шеша шеша
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   128/93818 [..............................] - ETA: 1:12 - loss: -0.5039 - mean_absolute_percentage_error: 1799.7618 - mean_absolute_error: 0.0173
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 93818/93818 [==============================] - 74s 787us/step - loss: -0.5102 - mean_absolute_percentage_error: 1888.8158 - mean_absolute_error: 0.0181 - val_loss: -0.5203 - val_mean_absolute_percentage_error: 1940.6578 - val_mean_absolute_error: 0.0188
# Сделается мне так душно, так душно дома, что бежала бы. И такая мысль придет на меня,
#               что, кабы моя воля, каталась бы я теперь по Волге, на лодке, с песнями, либо на тройке
#               на хорошей, обнявшись...
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# таак парок эак киг таак таак ладно нуда нихто таак зирка луда луда лешка дылда луда луда луда муда зирка таак зирка луда луда луда луда понь луда дылда луда луда дунюшка зирка луда луда луда луда луда луда луда луда луда луда луда луда луда луда луда луда луда
# Train on 93818 samples, validate on 23455 samples
# Epoch 1/1
#   128/93818 [..............................] - ETA: 1:15 - loss: -0.5324 - mean_absolute_percentage_error: 1583.0139 - mean_absolute_error: 0.0176
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# 70272/93818 [=====================>........] - ETA: 17s - loss: -0.5121 - mean_absolute_percentage_error: 2136.9164 - mean_absolute_error: 0.0201
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-e90826d77869> in <module>
#       5     out = [model.wv.most_similar(positive=[normalize([vec])[0],])[0][0] for vec in a]
#       6     print(' '.join(out))
# ----> 7     encoder_decoder.fit(X, X, validation_split=0.2, batch_size=128, epochs=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
def get_sent_vector(sent, functor):
    words = nltk.word_tokenize(sent)
    if len(words) > 0:
        sent_vecs = my_pad([model.get_vector(word) for word in words], 50)
        layer_outs = functor([[sent_vecs], 1.])
        return normalize(layer_outs[7])
    else:
        return None


inp = encoder_decoder.input                                           # input placeholder
outputs = [layer.output for layer in encoder_decoder.layers]          # all layer outputs
functor = K.function([inp, K.learning_phase()], outputs )   # evaluation function

# pairwise_distances(get_sent_vector('Всем привет', functor), 
#                    get_sent_vector('Всем по чашке', functor), 
#                    metric='euclidean')
get_sent_vector('Всем привет', functor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c958269927e2> in <module>
#      11
#      12
# ---> 13 inp = encoder_decoder.input                                           # input placeholder
#      14 outputs = [layer.output for layer in encoder_decoder.layers]          # all layer outputs
#      15 functor = K.function([inp, K.learning_phase()], outputs )   # evaluation function
#
# NameError: name 'encoder_decoder' is not defined

# %%
vectors = [get_sent_vector(sent, functor) for sent in tqdm(only_sents)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=117273.0), HTML(value='')))

# %%
X = [vector[0] for vector in tqdm(vectors)]
# for clust_num in [5, 10, 20, 40, 60, 100, 200]:
for clust_num in [20]:
    clust_model_kmeans = KMeans(n_clusters=clust_num, random_state=42, precompute_distances=True)
    clust_model_kmeans.fit(X)
    clusters = clust_model_kmeans.predict(X)
#     print('{}: {}'.format(clust_num, silhouette_score(X, clusters)))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=117273.0), HTML(value='')))

# %%
cluster_names = {}

for curr_cluster in sorted(list(set(clusters))):
    print(curr_cluster)
    sents_in_this_cluster = [sent for sent, cluster in sents_with_clusters if cluster==curr_cluster]
    for sent in random.choices(sents_in_this_cluster, k=20):
        print(sent)
    cluster_names[curr_cluster] = input()
    print('=========================\n=========================\n=========================\n\n\n')
cluster_names
# Out:
# 0
# Будет вам проказничать-то, уморили со смеху! Поцелуемтесь.
# Что за грабеж, а ступайте с богом, вот и все тут.
# Государь, мы тебя не узнали, Не суди же покорных рабов, Но скажи, чтобы мы разметали Этих низких и злобных волков.
# Приданое? — Какая ужасная весть! Верно, выдают Лизу! Надобно все узнать и во что бы
#               то ни стало разбить эту свадьбу.  Позвольте
#               сударыня, изъявить вам мою радость...
# Мерси. Не откажусь. Жарко, знаете, а тут все на ногах да на ногах.
# Ну, что, брат, нравится ль?
# Что вы говорите? Как вы, сударь, можете?..
# Помню, помню, ваше сиятельство: ты княжна Тройкина и, проживши девичьи лета, нейдешь
#               замуж для того, что надеешься быть графинею.
# Единым, боги, мя вы сыном утешали, Различными его дарами украшали, Во младости своей он тьмой великих дел Желание мое далеко превзошел, Он взнесся, сколько мог герой когда взнестися, От имени его весь Север стал трястися, Но, — о плачевный день! — то всё перемени, Героя, сына, всё ты отнял у меня!
# Ваш трашайший сын также на сфете как-нипудь фсмаститца, лютей пасматреть и сепя
#               покасать. Уталец!
# Я ведь не пойду за него; так к чему же эта комедия?
# С экзаментом своим, Как лист перед травой, перед тебя предстанет Максим Меркурьич.
# Я тебе покажу, сукин сын, парикмахера! Букли долой! Косу долой! Все долой!
# Но если ты не хочешь оценить Даров моих, позволь же мне, Марина, Слезами и коленопреклоненьем Молить любви твоей
# — Стой здесь, княжна. Выйдет царь, поклонись ему в ноги и проси за дядю.
# Ну, значит, умер! Слава Те, Господи!..  Аллилуйя, аллилуйя
#               и паки аллилуйя!Аллилуйя (евр.) -- хвалите Бога; паки
#                 (церковнослав.) -- снова.(Аллилуйя (евр.) -- хвалите Бога; паки
#                 (церковнослав.) -- снова.) С новым государем, кум! Поцелуемся...
# Свершилося! Так вот ты, царь Иван, Пред кем тряслась так долго Русь! Бессилен, Беспомощен лежишь ты, недвижим, И посреди твоих сокровищ беден! Чего же мы стоим и ждем, бояре? Во прахе ли пред нами быть тому, Пред кем полвека мы лежали в прахе? Иль страшно вам коснуться до него? Не бойтеся! Уж не откроет он Своих очей! Уж острого жезла Не схватит длань бессильная, и казни Не изрекут холодные уста!
# А!! Вот он как! Ну, так я с ним, с дружком... Я его! Я его!
# Комсомольского. Мы уже рассматривали ее заявление на бюро. И мы отвечаем теперь за
#               Машу.
# Вы совсем расстроены! — ваше лицо переменилось! ах! сударыня! — присядьте, ваши руки
#             дрожат! —
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /opt/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-218-8ce4261ad3ec> in <module>
#       6     for sent in random.choices(sents_in_this_cluster, k=20):
#       7         print(sent)
# ----> 8     cluster_names[curr_cluster] = input()
#       9     print('=========================\n=========================\n=========================\n\n\n')
#      10 cluster_names
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
def cluster_text(per_text, functor, cluster_model, cluster_names={}):
    output = []
    all_clusters = []
    for person, sent in per_text:
        sent_vec = get_sent_vector(sent, functor)
        if sent_vec is not None:
            cluster =  clust_model_kmeans.predict(sent_vec)[0]
            sents = {sent: cluster}
            output.append((person, sents))
            all_clusters.append(cluster)
    return output, all_clusters

parsed_text, _ = cluster_text(dramas_texts[201][2], functor, clust_model_kmeans)

for person, rep in parsed_text:
    print(person)
    for phrase in rep:
        print(phrase + ': ' + colored(rep[phrase], 'red'))
    print('\n')
# Out:
# Федор
# Вот уж который день, брат Христиан, Мы сходимся с тех пор, как ты помолвлен Со Ксенией, и каждый раз тебя, Мне кажется, мы оба больше любим, Могли б тебя мы слушать без конца, Но ты досель о родине нам только Рассказывал своей…: 11
#
#
# Ксения
# Да, королевич, Пора, чтоб ты нам о себе поведал. Уже давно спросить тебя хочу я: Как вырос ты? И как доселе жил? И как во Фландрии сражался?: 9
#
#
# Федор
# Все, Все расскажи нам, Христиан. Мы стали Теперь с тобой родные; вместе нам Пришлося жить, так надо знать друг друга!: 15
#
#
# Ксения
# Начни сначала. Детство нам свое Сперва скажи!: 3
#
#
# Христиан
# Несложная то повесть, Царевна, будет: мой отец, король, Со мной простясь, услал меня ребенком Из города в норвежский дальний замок И указал там жить — зачем? — не знаю. Мрачны картины первых лет моих: Среди туманов северной природы, Под шум валов и сосен вековых Прошли мои младенческие годы. Мне помнятся раскаты непогоды, Громады гор, что к небу вознеслись, С гранитных скал струящиеся воды И крутизна, где замок наш повис. Ребенком там, в мечтанье одиноком, Прибою моря часто я внимал Или следил за ним веселым оком, Когда в грозу катил за валом вал И, разбиваясь о крутые стены, Отпрядывал потоком белой пены. И с ранних пор сказанья старины, Морских бойцов походы и сраженья Отважные мне навевали сны, И вдаль меня манили приключенья. В один покой случайно я проник; Висели латы там под слоем пыли, А на столе лежало много книг — Норвежские то летописи были. Я стал читать — и ими, как огнем, Охвачен был сильнее с каждым днем, И ярче все являлись мне виденья: Богатыри, и схватки, и сраженья. Так время шло. Четырнадцати лет Я призван был в столицу. Новый свет Открылся мне. Я с радостию детской Предался жизни суетной и светской — Но ненадолго. Праздности моей Стыдиться стал я скоро. Прежних дней Воскресли сны и прежние виденья: Все те же сечи, схватки и сраженья. И думал я: настанет ли тот день, Когда мечта, которую с любовью Я все ловлю, как веющую тень, Оденется и плотию и кровью? И он настал. Вскипел великий бой, Священный бой за веру и свободу: Испании владыка встал войной, Грозя цепями вольному народу. Во Фландрию тогда Европы всей Стекалися единоверных рати — И из тюрьмы я вырвался моей На выручку преследуемых братий.: 7
#
#
# Федор
# Да, Христиан, мы слышали про то, Как ты с испанцем бился под Остендом. Счастлив же ты! Тебе уж двадцать лет! Ты мог уже свои изведать силы, Ты сам себя на деле испытал — А я!: 17
#
#
# Христиан
# Тебе, царевич, суждена Блистательнее доля. Ты стоишь Близ своего отца, чтоб у него Державою учиться управлять, Как те князья, которые отвсюду Съезжалися в испанский стан, учиться У Спинолы, у пармского вождя, Как управлять осадою.: 4
#
#
# Федор
# Ты прав; Отца пример перед собою видеть — То счастье для меня, и лучшей доли Я б не желал, как только научиться Ему в великом деле помогать. Но не легко дается та наука, А праздным быть несносно. Ты ж успел Узнать войну, ты отражал осаду, Ты слышал пушек гром, пищалей треск, Вокруг тебя летали ядра…: 15
#
#
# Христиан
# Да, И я узнал, что мужество и сила Должны теперь искусству уступать; Что не они уже решают битвы, Как в славные былые времена, И грустно мне то стало. Но меня Поддерживала мысль, что я служу Святому делу.: 18
#
#
# Ксения
# И за это мне Ты, королевич…: 9
#
#
# Федор
# Сразу полюбился? Так, Ксенья?: 11
#
#
# Ксения
# Так. Но я бы знать хотела, Его спросить хотела б я: как он Чужую мог заочно полюбить?: 18
#
#
# Христиан
# Легко мне дать ответ тебе, царевна: Ты не была чужая для меня! Царя Бориса чтит весь мир. Далеко О нем молва в Европе разнеслась; Кому ж его вблизи случалось видеть, Обвороженный возвращался тот На родину; но прославлял он столь же Величие правителя Русии, Сколь совершенства дочери его. Кто б ни был то, посланник, или пленный, Или купец ганзейский,— ни один Не забывал царевну Ксенью славить, Ее красу и ум превозносить И неземную, ангельскую кротость. Рассказы те в мою запали душу; А дальний твой, несхожий с нашим край, Все, что молва о нем к нам приносила: Разливы рек, безбережные степи, Снега и льды, обычай, столь отличный От нашего; державы христианской Азийский блеск, с преданьями отцов Нам общими,— все это, как нарочно, Набросило волшебный некий свет На образ твой. Ты мне предстала тою, С кем связан я таинственной судьбою… Тебя добыть не мыслил я тогда, Но образ твой светил мне как звезда, Приковывал мои невольно взоры — И в шуме битв, в пылу кипящих сил, Я, рыцаря заслуживая шпоры, Тебе, царевна, мысленно служил!: 5
#
#
# Федор
# Брат Христиан, как странно и как ново Мне речь твоя звучит! Не думал я, Чтоб можно было полюбить кого, Не знаючи иль не видав. Но правда Мне слышится в твоих словах, и вместе В них будто что-то чуется родное; И хорошо с тобой мне, Христиан, Так хорошо, как будто после долгой Разлуки я на родину вернулся. И Ксенья вот задумалась, смотри!: 15
#
#
# Ксения
# Задумалась я вправду. Новый мир Ты, королевич, мне открыл. У нас Не любят так. У нас отцы детей Посватают, не спрашивая их, И без любви друг к другу под венец Они идут. Я, признаюсь, всегда Дивилася тому.: 4
#
#
# Федор
# Обычай этот К нам от татар привился, а до них Вольна была невеста жениха Сама избрать.: 6
#
#
# Христиан
# Гаральд норвежский наш Дочь Ярослава русского посватал. Но не был он в ту пору знаменит И получил отказ от Ярославны. Тогда, в печали, бросился он в сечи, В Сицилии рубился много лет И в Африке, и наконец вернулся В град Киев он, победами богат И несказанной славою, и Эльса Гаральда полюбила.: 12
#
#
# Федор
# Да, в то время Стекалось в Киев много женихов. Другая Ярославна за Индрика Французского пошла, а третья дочь — За короля венгерского Андрея. Всем трем отец дал волю выбирать. Тогда у нас свободней, Христиан, И лучше было. В те поры у немцов Был мрак еще, а в Киеве считалось Уж сорок школ. Татары все сгубили.: 11
#
#
# Христиан
# Отец твой то, царевич, воскресит, Вознаградит потерянное время!: 2
#
#
# Ксения
# Да, Христиан. Но, верь мне, ты не знаешь Еще отца! Доселе видел ты Его дела; но если б видеть мог ты Его любовь к земле, его заботу, Его печаль о том, чего свершить Он не успел, его негодованье На тех людей, которые б хотели Опять идти по-старому,— и вместе Терпенье к ним, и милость без конца — Тогда бы ты узнал его!: 4
#
#
# Христиан
# Хотя бы Его не знал я вовсе — и тогда Он за любовь великую твою Мне б дорог стал!: 18
#
#
# Ксения
# Не потому его Люблю я, Христиан, что он отец мне; Нет, я за то люблю его, что он Так мало мыслит о себе!: 18
#
#
# Федор
# То правда; Лишь об одной земле его забота: Татарщину у нас он вывесть хочет, В родное хочет нас вернуть русло. Подумаешь: и сами ведь породой Мы хвастаться не можем; от татар ведь Начало мы ведем!: 15
#
#
# Христиан
# Но двести лет Вы русские. Татарской крови мало Осталось в вас.: 12
#
#
# Федор
# Ни капли не осталось! И вряд ли бы нашелся на Руси, Кто б ненавидел более татар, Чем мы с отцом.: 4
#
#
# Христиан
# Они навряд ли также Царя Бориса любят с той поры, Как он разбил, при Федоре, их силу!: 6
#
#
# Федор
# Ведь вот теперь сидим мы здесь втроем И говорим свободно, а в народе Ведь думают, что Ксеньи и доселе Ты не видал, что ты ее увидишь Лишь под венцом! А вместе показаться И думать вам нельзя, того обычай, Вишь, не велит! Хотелось бы мне знать: Когда она не пряталась, пока Невестой не была, зачем теперь Ей прятаться!: 4
#
#
# Ксения
# Нельзя, сказал отец, Все разом переделать; глубоко Пустил у нас чужой обычай корни И медленно выводится.: 11
#
#
# Федор
# К прискорбью! И матушка вот следует ему. Ей нелюбо, что видеться дозволил Вам двум отец. Она бы под замком Тебя держать хотела!: 8
#
#
# Ксения
# Не вини Ты нашу мать за это, королевич. Не всякому дано так ясно видеть, Как батюшке.: 15
#
#
# Федор
# Не то одно. Что грех Уж нам таить! Еще за то косится На Христиана наша мать, что он Не нашей веры.: 18
#
#
# Ксения
# Но ведь нашу веру, Не правда ль, примешь ты?: 11
#
#
# Христиан
# Не торопи Меня, царевна. В этом Бог волен. Учителей я ваших обещал С благоговеньем выслушать, но только По убежденью откажусь от веры Моих отцов.: 4
#
#
# Ксения
# Тогда спокойна я. Не можешь, королевич, не принять Ты нашей веры. Без греха могу я Тебя любить.: 18
#
#
# Федор
# А я уж и подавно! Дадим же мы втроем обет друг другу Любить друг друга, помогать друг другу, Не мыслить врозь и вместе жить всегда! Ты, Ксения, согласна?: 8
#
#
# Ксения
# Всей душой!: 2
#
#
# Федор
# Ты, Христиан?: 2
#
#
# Христиан
# И сердцем и душою!: 5
#
#
# Федор
# Но в тайне пусть союз наш остается! Тем крепче будет он. Подумай только, Чего не сможем сделать мы втроем! Ты нас учи всему, чем превосходна Твоя земля, а мы со Ксеньей будем Тебя знакомить с Русью!: 11
#
#
# Христиан
# Дай мне Бог Ей вместе с вами послужить!: 8
#
#
# Федор
# Втроем Мы воскресим то время, о котором В старинных книгах ты читал, когда Так близки были наши деды. Боже! Продли отцу его надолго дни, Чтоб Русью стала снова Русь!: 7
#
#
# Ксения
# Господь Услышь тебя, Феодор!: 6
#
#
# Стольник
# Царь идет!: 16
#
#
# Борис
# Я перервал ваш, дети, разговор. Вы горячо о чем-то толковали. Что, Христиан? Успел ты на Руси Обжиться с нами?: 17
#
#
# Федор
# Да, отец! Он русский! И русский он обычай перенял: Он на пути к Москве, себе в забаву, Смирял неезженых коней!: 12
#
#
# Борис
# Нам Власьев И Салтыков так донесли. Ты любишь Искать везде опасность, Христиан, То укрощать коней, то по волнам Ладьею править в бурю?: 12
#
#
# Христиан
# Государь, Я датчанин. Нам, как и русским, любо, Когда не трубит бранная труба, Изведывать уменье или силу Над чем пришлось.: 17
#
#
# Борис
# Но Ксении моей Твоя отвага даровая может Не по сердцу прийтись.: 6
#
#
# Христиан
# Царевна Ксенья! Скажи сама, по правде: жениха Ты робкого могла ли б полюбить?: 15
#
#
# Ксения
# Нет, королевич.: 6
#
#
# Борис
# Если бы у нас Была война, тогда бы, Христиан, Ты удаль мог свою нам показать!: 2
#
#
# Христиан
# О, помяни ж ты это слово, царь! И если кто войну тебе объявит, Дай русскую вести мне рать! Клянусь, Я победить врагов твоих сумею Иль умереть, отец мой, за тебя!: 4
#
#
# Федор
# А мне, отец, дозволь идти с ним вместе! Обоим нам дай кровью послужить Родной земле!: 11
#
#
# Борис
# Любезен мне ваш пыл И ваша доблесть, юноши, но Русь Ограждена от войн теперь надолго. Не чаем мы вторжения врагов; Соседние наперерыв державы Нам предлагают дружбу и союз; Совместников на царство мы не знаем; Незыблем наш и тверд стоит престол — И мирными придется вам делами Довольным быть.: 4
#
#
# Стольник
# Великий государь,— Боярин Годунов, Семен Никитич!: 2
#
#
# Борис
# Пускай войдет!: 6
#
#
# Федор
# Пойдем, брат Христиан, Пойдем, сестра. У батюшки дела!: 6
#
#
# Борис
# Что сталося с тобой? Чем так, Никитич, Встревожен ты?: 9
#
#
# Семен Годунов
# Великий государь, Есть чем тревожиться! Возникнул слух: Царевич жив!: 2
#
#
# Борис
# Жив кто?: 9
#
#
# Семен Годунов
# Царевич Дмитрий!: 6
#
#
# Борис
# С ума ты, что ль, сошел?: 16
#
#
# Семен Годунов
# И сам бы рад Так думать, царь; но с разных к нам сторон Все та же весть приходит: жив Димитрий!: 17
#
#
# Борис
# Кто слышал эту весть?: 2
#
#
# Семен Годунов
# На площадях, В корчмах, везде, где только два иль три Сойдутся человека, тотчас шепчут Они о том промеж себя.: 15
#
#
# Борис
# И что ж По-ихнему? Как тот царевич Дмитрий Воскреснуть мог?: 2
#
#
# Семен Годунов
# Все та же басня, царь!: 7
#
#
# Борис
# Какая басня? Говори!: 10
#
#
# Семен Годунов
# Ты помнишь — Когда, падучим схваченный недугом, Упал на нож и закололся он — Ты помнишь…: 7
#
#
# Борис
# Ну?: 6
#
#
# Семен Годунов
# Нагие оболгали Тебя, что будто…: 1
#
#
# Борис
# Помню басню их. Ну, что ж? Когда б и вправду так случилось, Как мог воскреснуть он?: 15
#
#
# Семен Годунов
# Убийцы, мол, Ошиблися — зарезали другого.: 17
#
#
# Борис
# Кто смеет это говорить? Его Весь Углич мертвым видел! Ошибиться Не мог никто! Клешнин и Шуйский, оба Его в соборе видели! Нет, нет, То слух пустой; рассеется он скоро, Как ветром дым. Но злостным на меня Я вижу умысел. Опять в том деле Меня винят. Забытую ту ложь Из пыли кто-то выкопал, чтоб ею Ко мне любовь Русии подорвать!: 4
#
#
# Семен Годунов
# Романовы Черкасских угощали Вчерашний день. За ужином у них Шла речь о том же. Слуги донесли.: 2
#
#
# Борис
# Романовы? Которых я щадил? Они молву ту распускают? Нет — Нет, этого терпеть нельзя!: 18
#
#
# Семен Годунов
# Давно бы Так, государь!: 2
#
#
# Борис
# Не будем торопиться — Их чтит народ…: 8
#
#
# Семен Годунов
# Лишь развяжи мне руки!: 5
#
#
# Борис
# Преступником в глазах народа царь Не может быть. Чист и безгрешен должен Являться он, чтобы не только воля Вершилася его без препинанья, Но чтоб в сердцах послушных как святыня Она жила! С Романовыми я Повременю. Но если кто в народе Дерзнет о слухе том лишь заикнуться — В тюрьму его! Ступай разведай, как И кем тот слух посеян на Москве? До корня докопайся — и о всем Мне донеси! Нет, этого нельзя, Нельзя терпеть! Хоть я не царь Иван, Но и не Федор также. Против воли Пришлось быть строгим. Человек не властен Идти всегда избранным им путем. Не можем мы предвидеть, что с дороги Отклонит нас. Решился твердо я Одной любовью править; но когда Держать людей мне невозможно ею — Им гнев явить и кару я сумею!: 4

# %%
dramas_names = []
cluster_vecs = []

for i, drama in tqdm(enumerate(dramas)):
    for part_num, part in enumerate(dramas_texts[i]):
        dramas_names.append(drama.split('.')[0] + '_{}_{}_{}'.format(i, part_num, len(part)))
        _, clusters = cluster_text(part, functor, clust_model_kmeans)
        cluster_vecs.append(clusters)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
cluster_vecs[:10]
# Out:
# [[10,
#   12,
#   19,
#   7,
#   15,
#   7,
#   10,
#   11,
#   5,
#   6,
#   15,
#   4,
#   11,
#   4,
#   6,
#   16,
#   10,
#   17,
#   6,
#   13,
#   14,
#   9,
#   17,
#   7],
#  [15, 17, 3, 4, 8, 18, 1, 15, 6, 10, 5, 18, 12, 4, 17],
#  [15, 15],
#  [13, 1, 9, 12, 0, 1, 6, 13, 15, 17],
#  [0, 10, 6, 10],
#  [6, 5, 11, 16, 17],
#  [4, 18, 17, 16, 4],
#  [6, 18, 18, 17, 9, 11, 1, 1, 4, 5, 11, 19, 4],
#  [9,
#   1,
#   10,
#   7,
#   15,
#   6,
#   17,
#   11,
#   3,
#   6,
#   10,
#   10,
#   1,
#   18,
#   1,
#   6,
#   2,
#   7,
#   14,
#   16,
#   2,
#   19,
#   14,
#   2,
#   10,
#   5,
#   14,
#   1,
#   14],
#  [7,
#   14,
#   7,
#   6,
#   13,
#   14,
#   14,
#   18,
#   0,
#   4,
#   7,
#   2,
#   2,
#   6,
#   10,
#   14,
#   2,
#   15,
#   8,
#   11,
#   11,
#   10,
#   16,
#   7,
#   10,
#   3,
#   18,
#   10,
#   6,
#   18,
#   19,
#   5,
#   6,
#   11,
#   7,
#   4,
#   14,
#   17,
#   5,
#   3,
#   12,
#   7,
#   5,
#   1,
#   12,
#   8,
#   7,
#   13,
#   7,
#   8,
#   17,
#   3,
#   11,
#   10,
#   12,
#   16,
#   0,
#   16,
#   1,
#   17,
#   17,
#   5,
#   13,
#   7,
#   8,
#   18,
#   10,
#   10,
#   17,
#   0,
#   11,
#   0,
#   14,
#   16,
#   12]]

# %%
clusters_transmission_graph = nx.Graph()

for cluster_vec in tqdm(cluster_vecs):
    if len(cluster_vec) >=2:
        for i in range(len(cluster_vec) - 1):
            left_clust = cluster_vec[i]
            right_clust = cluster_vec[i + 1]
            if clusters_transmission_graph.has_edge(left_clust, right_clust):
                clusters_transmission_graph[left_clust][right_clust]['weight'] += 1
            else:
                clusters_transmission_graph.add_edge(left_clust, right_clust, weight=1)

fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
pos = nx.spring_layout(clusters_transmission_graph)
nx.draw(clusters_transmission_graph, pos)
nx.draw_networkx_edges(clusters_transmission_graph, pos)
# nx.draw_networkx_labels(clusters_transmission_graph, pos, cluster_names, font_size=16)

print('done')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4635.0), HTML(value='')))
# done

# %%
from math import exp
all_weights = []

for (node1, node2, data) in clusters_transmission_graph.edges(data=True):
    all_weights.append(data['weight']) #we'll use this when determining edge thickness
        
unique_weights = list(set(all_weights))

fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

pos = nx.spring_layout(clusters_transmission_graph)
nx.draw_networkx_nodes(clusters_transmission_graph, pos)

for weight in unique_weights:
    weighted_edges = [(node1,node2) for (node1, node2, edge_attr) in 
                      clusters_transmission_graph.edges(data=True) if edge_attr['weight']==weight]
    width = (weight * 100 / sum(all_weights))**3
    nx.draw_networkx_edges(clusters_transmission_graph, pos, edgelist=weighted_edges, width=width)

# %%
btw_centrality = nx.centrality.betweenness_centrality(clusters_transmission_graph, normalized=True, weight='weight')
{k: v for k, v in sorted(btw_centrality.items(), key=lambda item: -item[1])}
# Out:
# {14: 0.2807017543859649,
#  10: 0.0,
#  12: 0.0,
#  19: 0.0,
#  7: 0.0,
#  15: 0.0,
#  11: 0.0,
#  5: 0.0,
#  6: 0.0,
#  4: 0.0,
#  16: 0.0,
#  17: 0.0,
#  13: 0.0,
#  9: 0.0,
#  3: 0.0,
#  8: 0.0,
#  18: 0.0,
#  1: 0.0,
#  0: 0.0,
#  2: 0.0}

# %%
sents_with_clusters = list(zip(only_sents, clust_model_kmeans.predict(X)))

# %%
# cluster_names = {}

# for curr_cluster in set(clust_model_kmeans.predict(X)):
for curr_cluster in [14]:
    print(curr_cluster)
    sents_in_this_cluster = [sent for sent, cluster in sents_with_clusters if cluster==curr_cluster]
    for sent in random.choices(sents_in_this_cluster, k=20):
        print(sent)
    cluster_names[curr_cluster] = input()
    print('=========================\n=========================\n=========================\n\n\n')
    
cluster_names
# Out:
# 14
# Да, да, это так.
# Ишь ты какая!
# Что ты задумалась?
# Ручка-то какая! хе, хе, хе... бархатная!
# А ты попроси.
# А ты?
# Я где-то видел твою ханжескую рожу. Не помню где, — я много видел на своем веку: в
#               суде, где ты внушал присяжным смертные приговоры; или в церкви, где ты проповедовал
#               смирение; или... да! здесь, на берегу, ты доказывал людям, что им не надо свободы.
# Подите! Оставьте меня!
# А ты много шумишь.
# А ты попроси.
# Вы, што ль, мне денег-то давали?
# Нет денег.
# Я тебя и манерам-то выучила. Как ты себя держал? Как ты стоял, как ты ходил? Ну, что
#               такое ты был на сцене? Цирюльник!
# Что водка? Меня выше водки подняло.
# . Воды! Воды!
# Охо, хо, хо!
# А! Я воскресаю!.. Оружие в моих руках! Я исторг его из рук соглядатая... Может быть,
#               он прибег из стана татар умертвить врага Кучумова во мраке ночи... Он умрет только от
#               руки Согдая... Ермак! Может быть, ты избегнул бы погибели и кто-нибудь другой пал бы
#               вместо тебя, но рука Согдая не сделает ошибки... Шатер и стража не защитят тебя...
#               Может быть, ты и во сне мечтаешь о славе и победах, но вместо их...  Кто здесь спит?.. Боже! Это сам
#               Ермак! О счастье! Ты подаешь мне случай отмстить за плен мой.  Умертвя тайно врага моего, с оружием в руках я пролечу
#               сквозь цепь казаков. Смерть Ермака изумит их, и потом -- пусть они все погибнут!..
# Так зачем же ты молчал? Зачем?
# Здравствуй, Франц, о чем ты задумался?
# Не со мной уж... так, ну, с кем?

# %%
node2vec = Node2Vec(clusters_transmission_graph, dimensions=2, walk_length=5, num_walks=5, workers=10)
embs = node2vec.fit(window=1, min_count=2)
# Out:
# Computing transition probabilities: 100%|██████████| 20/20 [00:00<00:00, 648.38it/s]
# /opt/anaconda3/lib/python3.7/site-packages/gensim/models/base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
import seaborn as sns

clust_to_vec_list = [embs[str(clust)] for clust in range(20)]

fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

sns.scatterplot(x=[x for x, y in clust_to_vec_list],
                y=[y for x, y in clust_to_vec_list])

plt.grid()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def list_of_clusters_to_vec(clusters, clust_to_vec):
    if len(clusters) > 0:
        return np.mean([clust_to_vec[clust] for clust in clusters], axis=0)
    else:
        return np.array([0] * len(clust_to_vec['0']))


drama2vec = []

for i, drama in tqdm(enumerate(dramas)):
    for part_num, part in enumerate(dramas_texts[i]):
        _, clusters = cluster_text(part, functor, clust_model_kmeans)
        drama2vec.append(list_of_clusters_to_vec([str(clust) for clust in clusters], embs))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 563

cos_dis = pairwise_distances(drama2vec, drama2vec, metric='euclidean')
dis_dict = {dramas_names[i]: dis for i, dis in enumerate(cos_dis[2551])}
{k: v for k, v in sorted(dis_dict.items(), key=lambda item: item[1])}
# Out:
# {'khmelnitsky-govorun_119_3_14': 0.0,
#  'mamin-sibirjak-malenkaja-pravda_65_44_10': 0.00040200078916303284,
#  'bulgakov-vojna-i-mir_69_24_38': 0.0005242104784679755,
#  'rostopchina-neludimka_7_14_15': 0.0009334081997563516,
#  'chekhov-na-bolshoi-doroge_170_0_63': 0.0009778809559107364,
#  'bulgakov-vojna-i-mir_69_29_32': 0.0009988232917967448,
#  'ostrovsky-puchina_50_7_55': 0.0012674658065220555,
#  'nekrasov-shila-v-meshke-ne-utaish_148_14_65': 0.0013028018842223565,
#  'turgenev-mesjats-v-derevne_4_1_378': 0.0013821343188752592,
#  'bulgakov-batum_111_0_235': 0.0014301208056570122,
#  'zagoskin-blagorodnyj-teatr_22_17_15': 0.0014593976893224711,
#  'ostrovsky-dohodnoe-mesto_124_18_23': 0.0017197393151123083,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_11_41': 0.0018257297568002883,
#  'bulgakov-poslednie-dni_27_3_125': 0.0018511951726560881,
#  'sumarokov-sinav-i-truvor_209_10_15': 0.0018556753856839659,
#  'knyazhnin-neudachnyj-primiritel_117_3_7': 0.0019695420866701037,
#  'ostrovsky-bednaja-nevesta_3_23_26': 0.002037422681331185,
#  'andreyev-ne-ubiy_31_4_194': 0.00203995154125586,
#  'fonvizin-nedorosl_149_12_47': 0.0021041314600254413,
#  'lensky-horosha-i-durna_112_0_14': 0.00219537067726379,
#  'lazhechnikov-okopirovalsya_153_7_18': 0.0023337409132113077,
#  'ostrovsky-poslednyaya-zhertva_125_44_44': 0.0023520566836858683,
#  'lermontov-menschen-und-leidenschaften_92_17_50': 0.002357140606603564,
#  'turgenev-zavtrak-u-predvoditelja_108_9_99': 0.002366955084125388,
#  'chekhov-vishnevyi-sad_87_2_130': 0.0023690710152617497,
#  'fonvizin-nedorosl_149_19_15': 0.002535221347648244,
#  'tolstoy-vlast-tmy_183_76_24': 0.002551892322700773,
#  'ostrovsky-les_90_26_49': 0.002597152884593275,
#  'turgenev-vecher-v-sorrente_63_0_226': 0.002600942438891206,
#  'ostrovsky-groza_147_24_112': 0.002676119196022278,
#  'andreyev-mysl_14_1_190': 0.0027293395624562217,
#  'bulgakov-beg_190_5_130': 0.0027302879189316973,
#  'shakhovskoy-urok-koketkam_176_2_30': 0.0027378156741356663,
#  'zagoskin-blagorodnyj-teatr_22_7_14': 0.0029615842125716688,
#  'lermontov-maskarad_193_6_56': 0.003066499969024681,
#  'krylov-amerikantsy_192_10_7': 0.0030785406023880425,
#  'majkov-agriopa_19_1_20': 0.003123608825663804,
#  'gogol-zhenitba_11_21_42': 0.003493246685744832,
#  'chekhov-chaika_49_0_189': 0.0035550454356943436,
#  'ostrovsky-vospitannica_177_22_43': 0.0035643973697104545,
#  'zagoskin-blagorodnyj-teatr_22_21_24': 0.0036386663340045103,
#  'turgenev-mesjats-v-derevne_4_4_285': 0.003648784914301897,
#  'fonvizin-korion_21_12_2': 0.003698974003716069,
#  'fonvizin-korion_21_20_2': 0.003698974003716069,
#  'knyazhnin-vadim-novgorodskij_32_0_2': 0.003698974003716069,
#  'kapnist-antigona_109_9_2': 0.003698974003716069,
#  'ekaterina-vtoraja-iz-zhizni-rjurika_188_15_2': 0.003698974003716069,
#  'kheraskov-plamena_191_3_4': 0.003698974003716069,
#  'glinka-velzen_36_15_11': 0.0037260065330789395,
#  'knyazhnin-hvastun_180_33_32': 0.003726220469496636,
#  'naydyonov-deti-vanjushina_85_2_227': 0.003732697184003669,
#  'andreyev-mysl_14_4_72': 0.0037532929404131945,
#  'ostrovsky-bogatye-nevesty_184_4_34': 0.003960807128277809,
#  'andreyev-ne-ubiy_31_3_194': 0.003980475056694814,
#  'andreyev-ne-ubiy_31_0_234': 0.004005859252326108,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_20_9': 0.004064760328896271,
#  'zagoskin-blagorodnyj-teatr_22_28_77': 0.00415455285099274,
#  'pushkin-skupoj-rytsar_166_0_57': 0.004224519091907693,
#  'kokoshkin-vospitanie_44_0_22': 0.004225444903323334,
#  'ostrovsky-vospitannica_177_10_7': 0.004225904053280779,
#  'afinogenov-mashenka_178_1_133': 0.004244144176131973,
#  'tolstoy-vlast-tmy_183_59_29': 0.0042679999660083555,
#  'ostrovsky-ne-ot-mira-sego_172_12_37': 0.004374283517777302,
#  'ostrovsky-bogatye-nevesty_184_8_39': 0.004594649079454661,
#  'sukhovo-kobylin-smert-tarelkina_40_30_47': 0.004607929263365124,
#  'ostrovsky-nevolnicy_162_23_54': 0.004634137640382485,
#  'pisarev-poezdka-v-kronshtadt_182_36_16': 0.004683623829667292,
#  'ostrovsky-dohodnoe-mesto_124_34_28': 0.004685754467487154,
#  'majkov-femist-i-ieronima_133_9_15': 0.004710932195889807,
#  'sumarokov-artistona_97_22_15': 0.004721504120371913,
#  'leskov-rastochitel_61_37_29': 0.00472730533269541,
#  'ostrovsky-puchina_50_6_10': 0.00483220383606887,
#  'ostrovsky-volki-i-ovtsy_129_44_43': 0.004838044938773047,
#  'ostrovsky-bednaja-nevesta_3_25_26': 0.004867928399699161,
#  'lomonosov-tamira-i-selim_51_15_5': 0.004886619255098307,
#  'ostrovsky-svoi-ljudi_128_6_18': 0.004888913926059305,
#  'ostrovsky-shutniki_120_22_73': 0.004951819662272696,
#  'chekhov-tri-sestry_101_0_223': 0.004970389671538585,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_12_25': 0.004979619877596223,
#  'ostrovsky-groza_147_36_36': 0.004988927214078539,
#  'turgenev-mesjats-v-derevne_4_3_203': 0.005032629193192661,
#  'griboyedov-molodye-suprugi_157_8_45': 0.005077748757379467,
#  'bulgakov-dni-turbinyh_46_4_151': 0.005119127235067533,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_19_75': 0.005142193175183847,
#  'gogol-lakeiskaja_0_4_4': 0.005292178002809052,
#  'tolstoy-zhivoy-trup_89_30_11': 0.005304722697433542,
#  'saltykov-shchedrin-smert-pazuhina_139_21_33': 0.0053050930499238475,
#  'krylov-urok-dochkam_198_10_28': 0.005486221315504929,
#  'ostrovsky-beshenye-dengi_91_44_29': 0.005494185591012448,
#  'chekhov-chaika_49_2_128': 0.005494491783375645,
#  'ostrovsky-les_90_5_51': 0.005624111539061429,
#  'naydyonov-deti-vanjushina_85_3_289': 0.005666625756747369,
#  'bulgakov-dni-turbinyh_46_3_64': 0.005667900821562017,
#  'mayakovsky-banja_115_3_33': 0.0056885511569159525,
#  'ekaterina-vtoraja-o-vremja_179_11_33': 0.005727245101399235,
#  'gogol-igroki_160_19_37': 0.005741717212815986,
#  'pushkin-boris-godunov_37_8_48': 0.0058276345704474505,
#  'krylov-modnaja-lavka_197_34_16': 0.005872909381876406,
#  'ostrovsky-ne-soshlis-harakterami_181_10_19': 0.005898222662213728,
#  'saltykov-shchedrin-smert-pazuhina_139_9_26': 0.005988310561200418,
#  'ostrovsky-bogatye-nevesty_184_20_36': 0.006039157616536912,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_11_61': 0.006060738595792313,
#  'bulgakov-batum_111_3_117': 0.006061443888835112,
#  'ostrovsky-nevolnicy_162_15_22': 0.00610591950267982,
#  'bulgakov-ivan-vasilevich_171_0_134': 0.0061826896814206,
#  'turgenev-neostorozhnost_99_0_93': 0.006192380846464703,
#  'ostrovsky-bednaja-nevesta_3_24_38': 0.006213229021463126,
#  'sumarokov-dimitrij-samozvanets_84_25_6': 0.006304880327025758,
#  'knyazhnin-hvastun_180_4_63': 0.006434737302296013,
#  'mamin-sibirjak-malenkaja-pravda_65_29_7': 0.006437433570979264,
#  'lermontov-strannyj-chelovek_39_4_74': 0.006479975810651124,
#  'sumarokov-horev_66_2_19': 0.0064956000051808495,
#  'tolstoy-smert-ioanna-groznogo_145_1_132': 0.0065095220643847825,
#  'turgenev-nahlebnik_86_1_331': 0.006525026331380457,
#  'afinogenov-mashenka_178_3_157': 0.006541628475388601,
#  'ostrovsky-puchina_50_8_42': 0.006568261316298818,
#  'ostrovsky-shutniki_120_9_21': 0.006589561243076451,
#  'ostrovsky-poslednyaya-zhertva_125_23_21': 0.006650539885838506,
#  'krylov-prokazniki_142_16_33': 0.006656882591470672,
#  'ostrovsky-na-bojkom-meste_68_5_39': 0.006694139651621023,
#  'ostrovsky-poslednyaya-zhertva_125_19_21': 0.0066982663120183595,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_22_29': 0.006741020244709127,
#  'shakhovskoy-ne-lubo-ne-slushai_33_13_145': 0.006749387898842624,
#  'sumarokov-ssora-u-muzha-s-zhenoj_206_2_17': 0.006764751246209898,
#  'lermontov-menschen-und-leidenschaften_92_0_14': 0.006901349927702464,
#  'gogol-revizor_23_33_33': 0.00690238378174055,
#  'ostrovsky-trudovoj-hleb_16_34_40': 0.006917945833292153,
#  'chekhov-na-bolshoi-doroge_170_4_27': 0.007027253610750695,
#  'shakhovskoy-urok-koketkam_176_29_27': 0.007033108579935329,
#  'chekhov-ivanov_169_5_26': 0.007039355076044136,
#  'ostrovsky-nevolnicy_162_3_29': 0.007054767122310405,
#  'sumarokov-pridanoe-obmanom_8_5_68': 0.007055975453259903,
#  'kedrin-rembrandt_79_15_26': 0.007075675049124899,
#  'turgenev-zavtrak-u-predvoditelja_108_7_43': 0.007089373273967667,
#  'ostrovsky-svoi-sobaki-gryzutsya-chuzhaya-ne-pristavaj_13_5_59': 0.007275871764706138,
#  'belsky-skazanie-o-nevidimom-grade-kitezhe_186_1_70': 0.007278158809320753,
#  'ostrovsky-bogatye-nevesty_184_17_49': 0.007322316156483253,
#  'ostrovsky-bednost-ne-porok_78_26_17': 0.007347747111749393,
#  'ostrovsky-shutniki_120_3_44': 0.007364904367998152,
#  'sollogub-chinovnik_88_15_24': 0.007459396839165633,
#  'chekhov-vishnevyi-sad_87_0_221': 0.0074638706539590085,
#  'gumilyov-don-zhuan-v-egipte_28_0_76': 0.007512836310372586,
#  'kedrin-rembrandt_79_23_19': 0.007516852614925693,
#  'chekhov-ivanov_169_22_11': 0.007525165224320549,
#  'kapnist-yabeda_132_32_91': 0.007545113182917454,
#  'nekrasov-akter_9_6_26': 0.0075542187737757185,
#  'chekhov-ivanov_169_28_21': 0.007561928255356223,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_1_35': 0.007585330637577679,
#  'ostrovsky-groza_147_2_48': 0.007599946120464509,
#  'mamin-sibirjak-malenkaja-pravda_65_46_10': 0.007760362497466283,
#  'tolstoy-tsar-boris_201_7_70': 0.007772449172194593,
#  'tolstoy-vlast-tmy_183_17_25': 0.007799533089851843,
#  'pisemskij-gorkaja-sudbina_105_19_23': 0.007805408059144563,
#  'lermontov-strannyj-chelovek_39_3_30': 0.007810123659272846,
#  'ostrovsky-bednaja-nevesta_3_43_16': 0.007832911389664046,
#  'ekaterina-vtoraja-o-vremja_179_0_25': 0.007841914615095915,
#  'ostrovsky-trudovoj-hleb_16_24_46': 0.00790523796849333,
#  'krylov-pirog_107_1_57': 0.007907340458093454,
#  'gogol-zhenitba_11_36_47': 0.007930150088300947,
#  'ostrovsky-puchina_50_18_63': 0.007994660916430732,
#  'griboyedov-gore-ot-uma_102_14_33': 0.008000480119705843,
#  'gumilyov-gondla_70_16_19': 0.008015284613056783,
#  'mamin-sibirjak-zolotopromyshlenniki_131_19_25': 0.008039972962989583,
#  'kropotov-fomushka_12_21_21': 0.00804486049195982,
#  'sumarokov-horev_66_0_14': 0.008066592551026533,
#  'zagoskin-blagorodnyj-teatr_22_44_27': 0.008108445128556553,
#  'bulgakov-poslednie-dni_27_2_159': 0.008140791743881647,
#  'sumarokov-vzdorschitsa_48_6_2': 0.008143766504871862,
#  'knyazhnin-didona_196_16_2': 0.008143766504871862,
#  'sumarokov-vzdorschitsa_48_11_16': 0.008149775854320016,
#  'sukhovo-kobylin-svadba-krechinskogo_55_21_36': 0.008162424889378416,
#  'bulgakov-adam-i-eva_76_1_180': 0.008179574405722657,
#  'ostrovsky-poslednyaya-zhertva_125_20_52': 0.008179876788489427,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_6_27': 0.008217084620745862,
#  'gogol-revizor_23_13_42': 0.008222412419295031,
#  'ostrovsky-neozhidannyj-sluchaj_189_1_146': 0.008258103611688921,
#  'nikolev-samolyubivyj-stihotvorec_20_13_24': 0.008275308471043807,
#  'ozerov-dmitrij-donskoj_159_12_24': 0.008283124149315601,
#  'ostrovsky-beshenye-dengi_91_24_15': 0.008287121873445462,
#  'gogol-teatralnyi-razezd_156_0_279': 0.008300815203875584,
#  'shakhovskoy-svoya-semya_146_7_19': 0.008310017779703874,
#  'knyazhnin-vadim-novgorodskij_32_12_7': 0.008312509125758056,
#  'tolstoy-tsar-boris_201_11_69': 0.008319907314160335,
#  'dashkova-toisiokov_73_31_2': 0.008336217320078325,
#  'nekrasov-akter_9_9_56': 0.008363067506706241,
#  'turgenev-holostjak_15_2_294': 0.00836690467184541,
#  'babel-zakat_135_3_36': 0.008387904563081389,
#  'petrov-ostrov-mira_130_25_10': 0.008411529233505511,
#  'ostrovsky-goryachee-serdce_98_33_17': 0.008436090105750376,
#  'ostrovsky-v-chuzhom-piru-pohmelje_144_13_39': 0.00844506549522309,
#  'ostrovsky-bez-viny-vinovatye_53_16_49': 0.008476159994226467,
#  'knyazhnin-hvastun_180_43_22': 0.008484003293258166,
#  'saltykov-shchedrin-smert-pazuhina_139_29_16': 0.008557729598986456,
#  'ostrovsky-puchina_50_11_78': 0.008559937896820495,
#  'gogol-revizor_23_18_9': 0.008594298084353219,
#  'babel-zakat_135_0_112': 0.008616904812732891,
#  'fonvizin-nedorosl_149_14_46': 0.008663859027690745,
#  'khmelnitsky-vozdushnye-zamki_165_6_22': 0.00870199995834631,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_28_39': 0.008704807030006919,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_16_57': 0.00877085039751876,
#  'lermontov-menschen-und-leidenschaften_92_4_36': 0.008779889361487417,
#  'ostrovsky-snegurochka_152_19_15': 0.008784564040768241,
#  'gogol-zhenitba_11_15_25': 0.008831820829228353,
#  'gogol-igroki_160_9_36': 0.008875829001784142,
#  'griboyedov-gore-ot-uma_102_50_12': 0.008890111362319554,
#  'sollogub-chinovnik_88_0_77': 0.00889933869986641,
#  'ozerov-dmitrij-donskoj_159_19_21': 0.008911885570884324,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_12_78': 0.008924282042195274,
#  'naydyonov-deti-vanjushina_85_0_287': 0.008965391944988348,
#  'tolstoy-zhivoy-trup_89_50_37': 0.008984055762787073,
#  'griboyedov-gore-ot-uma_102_46_7': 0.008986772479211402,
#  'ostrovsky-trudovoj-hleb_16_19_15': 0.009030206213961361,
#  'ostrovsky-shutniki_120_2_39': 0.009044066959138217,
#  'saltykov-shchedrin-smert-pazuhina_139_11_45': 0.009053695762795985,
#  'knyazhnin-chudaki_199_35_25': 0.0090787631308489,
#  'gogol-zhenitba_11_7_27': 0.00910574680623548,
#  'khmelnitsky-vozdushnye-zamki_165_13_29': 0.009144291181695262,
#  'fonvizin-brigadir_134_19_32': 0.009157919397242347,
#  'afinogenov-mashenka_178_2_94': 0.009160876143053323,
#  'ostrovsky-pozdnyaya-lyubov_52_29_53': 0.00923084874215374,
#  'nikolev-samolyubivyj-stihotvorec_20_34_27': 0.009328869816540412,
#  'shakhovskoy-svoya-semya_146_3_15': 0.009348812847049824,
#  'chekhov-ivanov_169_36_20': 0.009372800217153452,
#  'chekhov-svadba_173_0_154': 0.009461018190403101,
#  'lazhechnikov-okopirovalsya_153_16_35': 0.009461865648743895,
#  'chekhov-tri-sestry_101_1_224': 0.009498631104224428,
#  'sukhovo-kobylin-delo_138_2_37': 0.009503139441506778,
#  'ostrovsky-ne-ot-mira-sego_172_15_18': 0.009504827675080263,
#  'shakhovskoy-urok-koketkam_176_17_109': 0.009517141915343369,
#  'sollogub-chinovnik_88_12_64': 0.009538339065356167,
#  'merezhkovsky-pavel-pervyj_185_0_223': 0.009567485485181368,
#  'ostrovsky-nevolnicy_162_14_47': 0.00959135515116203,
#  'mamin-sibirjak-malenkaja-pravda_65_3_26': 0.009596419331649389,
#  'tolstoy-vlast-tmy_183_54_40': 0.009607551703735237,
#  'pisemskij-gorkaja-sudbina_105_2_12': 0.0096098616771078,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_18_28': 0.00965977037045464,
#  'turgenev-zavtrak-u-predvoditelja_108_1_36': 0.009661283190618217,
#  'ostrovsky-puchina_50_19_22': 0.009703033717303685,
#  'mamin-sibirjak-malenkaja-pravda_65_1_17': 0.009773049188875562,
#  'ostrovsky-trudovoj-hleb_16_23_27': 0.009792563539043302,
#  'petrov-ostrov-mira_130_48_13': 0.009821639326490736,
#  'plavilshchikov-ermak-pokoritel-sibiri_194_9_15': 0.00982176078311334,
#  'tolstoy-tsar-fedor-ioannovich_143_8_78': 0.009831876597774441,
#  'majkov-agriopa_19_26_13': 0.009836522379356515,
#  'pushkin-boris-godunov_37_3_14': 0.009851754439293356,
#  'ostrovsky-trudovoj-hleb_16_13_23': 0.009892923010991584,
#  'ostrovsky-svoi-ljudi_128_21_56': 0.009902760382653957,
#  'kropotov-fomushka_12_5_22': 0.009907755123379259,
#  'andreyev-ne-ubiy_31_1_110': 0.009915980740259895,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_29_38': 0.009944327969366708,
#  'fonvizin-nedorosl_149_24_42': 0.009954110639177347,
#  'ostrovsky-bez-viny-vinovatye_53_25_39': 0.009985877896859252,
#  'ostrovsky-pozdnyaya-lyubov_52_12_56': 0.010022511194184642,
#  'knyazhnin-chudaki_199_13_22': 0.010030698330638214,
#  'shakhovskoy-urok-koketkam_176_14_47': 0.010062335845323858,
#  'tolstoy-zhivoy-trup_89_70_23': 0.010117503286741436,
#  'majkov-femist-i-ieronima_133_11_8': 0.010133399193116979,
#  'tolstoy-vlast-tmy_183_0_8': 0.010157674147359599,
#  'kropotov-fomushka_12_34_28': 0.010206030822231307,
#  'ostrovsky-poslednyaya-zhertva_125_12_83': 0.010222268809105166,
#  'lomonosov-demofont_80_17_12': 0.010226135977879998,
#  'sumarokov-sinav-i-truvor_209_14_16': 0.010227466948880118,
#  'sukhovo-kobylin-svadba-krechinskogo_55_12_78': 0.010231163922541538,
#  'chekhov-na-bolshoi-doroge_170_1_90': 0.010233882559966935,
#  'blok-neznakomka_6_0_60': 0.0102570301388401,
#  'pushkin-boris-godunov_37_12_5': 0.01030333531373917,
#  'zagoskin-blagorodnyj-teatr_22_9_82': 0.010317583028391988,
#  'ozerov-dmitrij-donskoj_159_20_9': 0.010320298522818228,
#  'pisarev-naslednica_54_3_49': 0.010321732515151328,
#  'sumarokov-opekun_2_18_14': 0.010323522461383192,
#  'ostrovsky-puchina_50_4_49': 0.010343199339822464,
#  'ostrovsky-dohodnoe-mesto_124_30_60': 0.010345156089658808,
#  'gogol-revizor_23_32_24': 0.010375615404855038,
#  'ostrovsky-tyazhelye-dni_200_9_40': 0.010458487294061142,
#  'ostrovsky-les_90_21_14': 0.010491274464119432,
#  'ostrovsky-ne-tak-zhivi-kak-hochetsya_75_18_20': 0.01052198832500261,
#  'pushkin-boris-godunov_37_0_22': 0.010530814719126737,
#  'babel-zakat_135_6_94': 0.010567587072808882,
#  'plavilshchikov-sgovor-kutejkina_110_8_42': 0.01057623366026924,
#  'lermontov-strannyj-chelovek_39_5_26': 0.010578411550362559,
#  'pisarev-naslednica_54_13_33': 0.010591049984738126,
#  'mamin-sibirjak-zolotopromyshlenniki_131_31_14': 0.010598477362139475,
#  'ostrovsky-trudovoj-hleb_16_10_66': 0.010599101058730714,
#  'ostrovsky-groza_147_0_33': 0.010602569075585244,
#  'pisemskij-gorkaja-sudbina_105_22_26': 0.010630914749915845,
#  'andreyev-k-zvezdam_150_1_285': 0.010640234858027701,
#  'gogol-zhenitba_11_44_9': 0.01064031829220985,
#  'ostrovsky-nevolnicy_162_5_37': 0.010684414634988704,
#  'ekaterina-vtoraja-iz-zhizni-rjurika_188_24_27': 0.01072425486467663,
#  'knyazhnin-vadim-novgorodskij_32_5_23': 0.010728203039904578,
#  'lermontov-menschen-und-leidenschaften_92_19_10': 0.010738178830105057,
#  'turgenev-zavtrak-u-predvoditelja_108_4_27': 0.010744050885944531,
#  'khmelnitsky-svetskiy-sluchay_164_2_23': 0.010771233709851105,
#  'ostrovsky-beshenye-dengi_91_14_62': 0.010776507706121017,
#  'ostrovsky-bednost-ne-porok_78_11_28': 0.010782130186851748,
#  'ostrovsky-les_90_11_18': 0.010810015677015986,
#  'lazhechnikov-okopirovalsya_153_24_26': 0.010872356470317262,
#  'kapnist-yabeda_132_8_57': 0.010923406071595329,
#  'ostrovsky-groza_147_38_38': 0.010928994496690476,
#  'ostrovsky-dohodnoe-mesto_124_4_8': 0.010957945101983429,
#  'ostrovsky-volki-i-ovtsy_129_10_70': 0.010969506100021254,
#  'knyazhnin-vadim-novgorodskij_32_20_4': 0.010971031674819985,
#  'chekhov-ivanov_169_11_24': 0.010972560123865115,
#  'sukhovo-kobylin-smert-tarelkina_40_6_48': 0.010981400608652334,
#  'sukhovo-kobylin-svadba-krechinskogo_55_3_26': 0.011000791226450415,
#  'ostrovsky-volki-i-ovtsy_129_4_22': 0.011016015804094729,
#  'tolstoy-vlast-tmy_183_1_7': 0.011026804996950712,
#  'ostrovsky-snegurochka_152_16_35': 0.01102896636944254,
#  'ostrovsky-beshenye-dengi_91_26_19': 0.011053085702469595,
#  'kedrin-rembrandt_79_3_54': 0.011057761409837635,
#  'tolstoy-vlast-tmy_183_16_3': 0.011064952126657566,
#  'ostrovsky-goryachee-serdce_98_42_49': 0.011085383685178396,
#  'bulgakov-adam-i-eva_76_3_180': 0.011086308133435425,
#  'zagoskin-blagorodnyj-teatr_22_40_34': 0.011112248393469864,
#  'ostrovsky-pozdnyaya-lyubov_52_10_75': 0.011144858246288459,
#  'kapnist-yabeda_132_5_31': 0.011161059489405557,
#  'turgenev-nahlebnik_86_0_439': 0.011161747352204047,
#  'krylov-modnaja-lavka_197_4_17': 0.011193064997197247,
#  'chekhov-ivanov_169_6_24': 0.011236036642479973,
#  'ostrovsky-bednaja-nevesta_3_26_12': 0.011323453772178768,
#  'mayakovsky-klop_113_2_38': 0.011355317611737154,
#  'griboyedov-gore-ot-uma_102_11_37': 0.011374339660133573,
#  'kheraskov-osvobozhdennaja-moskva_203_3_5': 0.011386070819604716,
#  'shakhovskoy-pustodomy_56_32_17': 0.011458896731718482,
#  'mamin-sibirjak-malenkaja-pravda_65_9_21': 0.011477518963309676,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_5_39': 0.011497277729875414,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_11_16': 0.011521829421793818,
#  'ostrovsky-volki-i-ovtsy_129_5_21': 0.01152445375695903,
#  'chekhov-predlozhenie_140_3_31': 0.011531568882274251,
#  'leskov-rastochitel_61_39_79': 0.011583840628678196,
#  'bulgakov-dni-turbinyh_46_0_231': 0.011596894106290922,
#  'chekhov-leshii_71_21_16': 0.011624272556760342,
#  'mamin-sibirjak-zolotopromyshlenniki_131_44_23': 0.011626561503373154,
#  'kapnist-yabeda_132_31_20': 0.011627599955349389,
#  'tolstoy-vlast-tmy_183_35_13': 0.01163257842649025,
#  'fonvizin-korion_21_21_10': 0.011638742878083842,
#  'chekhov-leshii_71_42_30': 0.011651261269976518,
#  'shakhovskoy-urok-koketkam_176_1_43': 0.011732159268088117,
#  'fonvizin-korion_21_10_16': 0.011759894584922399,
#  'ostrovsky-bez-viny-vinovatye_53_26_24': 0.011773360951160031,
#  'babel-marija_205_5_41': 0.011839799472778568,
#  'krylov-prokazniki_142_43_24': 0.011862717807571008,
#  'pushkin-rusalka_151_1_26': 0.011875050189658976,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_21_60': 0.011875769149047385,
#  'majkov-agriopa_19_17_11': 0.011897999781027159,
#  'pisarev-lukavin_158_16_14': 0.01190012095403477,
#  'bulgakov-vojna-i-mir_69_10_18': 0.011910325063049999,
#  'ostrovsky-ne-tak-zhivi-kak-hochetsya_75_0_12': 0.011913629827436033,
#  'ostrovsky-nevolnicy_162_11_39': 0.011922992000858081,
#  'ostrovsky-poslednyaya-zhertva_125_33_22': 0.01193725040042369,
#  'khmelnitsky-svetskiy-sluchay_164_13_10': 0.011960988511253514,
#  'pisarev-naslednica_54_1_55': 0.012027509635841371,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_19_27': 0.012127084678102066,
#  'glinka-velzen_36_18_30': 0.012167153093539673,
#  'blok-neznakomka_6_1_76': 0.012179237645992136,
#  'bulgakov-vojna-i-mir_69_14_70': 0.012194652321101753,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_2_8': 0.012396514540592075,
#  'kokoshkin-vospitanie_44_2_78': 0.012418381277798301,
#  'ostrovsky-v-chuzhom-piru-pohmelje_144_9_28': 0.012428694775658227,
#  'chekhov-ivanov_169_13_6': 0.012454549902819394,
#  'kropotov-fomushka_12_2_15': 0.012458567525858843,
#  'khmelnitsky-vzaimnye-ispytaniya_17_9_54': 0.012513150828876687,
#  'sumarokov-semira_93_27_32': 0.012527436681463713,
#  'lazhechnikov-okopirovalsya_153_4_18': 0.012531108148402565,
#  'sollogub-chinovnik_88_5_79': 0.012606571073081878,
#  'leskov-rastochitel_61_16_34': 0.012624911753121141,
#  'shakhovskoy-pustodomy_56_7_25': 0.01267839411659282,
#  'plavilshchikov-ermak-pokoritel-sibiri_194_22_23': 0.012698964802617386,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_26_114': 0.012711691981390263,
#  'ostrovsky-na-bojkom-meste_68_14_41': 0.012739258781295872,
#  'shakhovskoy-pustodomy_56_5_39': 0.012754030402282084,
#  'sollogub-chinovnik_88_11_50': 0.012777174984768607,
#  'tolstoy-tsar-fedor-ioannovich_143_1_57': 0.012789423218692104,
#  'bulgakov-ivan-vasilevich_171_2_234': 0.012804872435494295,
#  'gogol-igroki_160_8_13': 0.012817641949155363,
#  'bulgakov-zojkina-kvartira_35_1_420': 0.012819412936726195,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_16_37': 0.012834997893763014,
#  'sumarokov-rogonosets-po-voobrazheniju_100_28_33': 0.012885387991749318,
#  'nikolev-samolyubivyj-stihotvorec_20_3_22': 0.012891971278902216,
#  'zagoskin-blagorodnyj-teatr_22_30_45': 0.012926634499399686,
#  'turgenev-provintsialka_175_21_40': 0.013012045899242767,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_3_37': 0.013020141293930162,
#  'gogol-revizor_23_50_82': 0.013028768726889949,
#  'tolstoy-vlast-tmy_183_74_24': 0.01306724168823478,
#  'krylov-urok-dochkam_198_8_52': 0.01308177370251058,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_35_15': 0.013136285250023706,
#  'gogol-zhenitba_11_17_28': 0.01316678773990542,
#  'zagoskin-blagorodnyj-teatr_22_5_21': 0.01317042341014441,
#  'chekhov-noch-pered-sudom_202_0_74': 0.01318571385531159,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_7_109': 0.013200784652148549,
#  'turgenev-mesjats-v-derevne_4_2_321': 0.013205867837520278,
#  'ostrovsky-groza_147_10_57': 0.013213190893467525,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_1_87': 0.013241740852737422,
#  'gorky-egor-bulychov-i-drugie_62_0_293': 0.013246365403648666,
#  'kapnist-yabeda_132_7_42': 0.013269739908538225,
#  'turgenev-zavtrak-u-predvoditelja_108_5_33': 0.013298367654950603,
#  'krylov-podschipa-ili-trumf_58_10_30': 0.013300032884568552,
#  'ostrovsky-bednaja-nevesta_3_48_50': 0.013301617366865538,
#  'gogol-zhenitba_11_1_29': 0.013312864348160548,
#  'lermontov-strannyj-chelovek_39_6_48': 0.013328872594372033,
#  'ostrovsky-svoi-ljudi_128_34_48': 0.013330895133230459,
#  'ostrovsky-prazdnichnyj-son-do-obeda_207_7_40': 0.013348478948538592,
#  'gorky-egor-bulychov-i-drugie_62_2_300': 0.013352616597816174,
#  'ostrovsky-snegurochka_152_13_26': 0.013374344928557555,
#  'lermontov-strannyj-chelovek_39_0_58': 0.01338222246047173,
#  'lermontov-menschen-und-leidenschaften_92_11_24': 0.01342418008580642,
#  'rostopchina-neludimka_7_10_15': 0.013474881853325911,
#  'andreyev-k-zvezdam_150_0_253': 0.013478781075080918,
#  'krylov-prokazniki_142_62_20': 0.013488625609221603,
#  'ostrovsky-bez-viny-vinovatye_53_3_16': 0.013533604111530671,
#  'ostrovsky-svoi-ljudi_128_19_8': 0.013575432558739293,
#  'tolstoy-zhivoy-trup_89_65_33': 0.01359024640190544,
#  'gogol-revizor_23_31_19': 0.013622769692115275,
#  'khmelnitsky-svetskiy-sluchay_164_5_63': 0.013641231108739696,
#  'ostrovsky-beshenye-dengi_91_0_49': 0.013655614754612277,
#  'lomonosov-demofont_80_12_15': 0.013673105479671942,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_13_42': 0.013689448192482152,
#  'krylov-prokazniki_142_49_11': 0.013690896545184728,
#  'ostrovsky-les_90_9_114': 0.013691309033375306,
#  'ostrovsky-bednaja-nevesta_3_53_37': 0.013700509409526747,
#  'sumarokov-ssora-u-muzha-s-zhenoj_206_17_17': 0.013705305604755063,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_14_26': 0.013714401672396178,
#  'sumarokov-pridanoe-obmanom_8_7_27': 0.013715227788527285,
#  'zagoskin-blagorodnyj-teatr_22_20_24': 0.013717308315671108,
#  'shakhovskoy-pustodomy_56_13_95': 0.013721675253836033,
#  'zagoskin-blagorodnyj-teatr_22_16_162': 0.013751222316371176,
#  'majkov-agriopa_19_12_9': 0.013753715535487952,
#  'lazhechnikov-okopirovalsya_153_1_30': 0.013778111588953106,
#  'kapnist-antigona_109_7_5': 0.013806270735829105,
#  'turgenev-zavtrak-u-predvoditelja_108_3_18': 0.01382218630536516,
#  'naydyonov-deti-vanjushina_85_1_232': 0.013843379691600922,
#  'ostrovsky-bespridannitsa_83_21_15': 0.01384639069499738,
#  'leskov-rastochitel_61_22_3': 0.013884573776121668,
#  'prutkov-oprometchivyj-turka_72_0_34': 0.01389532956777627,
#  'sukhovo-kobylin-delo_138_0_111': 0.013898454021914652,
#  'ostrovsky-goryachee-serdce_98_41_9': 0.013898982263047336,
#  'fonvizin-brigadir_134_23_30': 0.013899295738842403,
#  'ostrovsky-vospitannica_177_6_49': 0.013915344574907756,
#  'sumarokov-horev_66_19_22': 0.0139314616948389,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_27_4': 0.013951816624867639,
#  'krylov-prokazniki_142_38_23': 0.013998761739700827,
#  'shakhovskoy-urok-koketkam_176_30_19': 0.014024935520011002,
#  'fonvizin-brigadir_134_5_31': 0.014042616359618697,
#  'gogol-zhenitba_11_41_5': 0.014091042924461073,
#  'griboyedov-molodye-suprugi_157_12_38': 0.014134938286490898,
#  'mamin-sibirjak-zolotopromyshlenniki_131_17_12': 0.01415632544432812,
#  'sudovshchikov-neslyhannoe-divo_114_29_36': 0.014156974874455705,
#  'chekhov-leshii_71_28_20': 0.014157226452527009,
#  'griboyedov-gore-ot-uma_102_42_9': 0.014169543756931326,
#  'saltykov-shchedrin-smert-pazuhina_139_18_13': 0.014203535539990517,
#  'ostrovsky-utro-molodogo-cheloveka_155_2_25': 0.014232551908901669,
#  'chekhov-jubilej_57_0_133': 0.014238475268007231,
#  'pisarev-lukavin_158_40_26': 0.014266769788991622,
#  'mamin-sibirjak-malenkaja-pravda_65_27_16': 0.014310811248301221,
#  'mamin-sibirjak-zolotopromyshlenniki_131_48_21': 0.014323495068458012,
#  'bulgakov-vojna-i-mir_69_21_17': 0.014381974748224221,
#  'tolstoy-zhivoy-trup_89_40_29': 0.014403059634061086,
#  'bulgakov-adam-i-eva_76_2_218': 0.014405330809617988,
#  'zagoskin-blagorodnyj-teatr_22_35_14': 0.014432089797875499,
#  'sukhovo-kobylin-smert-tarelkina_40_26_39': 0.014442344443448735,
#  'ostrovsky-volki-i-ovtsy_129_43_12': 0.014464042078278455,
#  'ostrovsky-bespridannitsa_83_23_34': 0.014481827541375947,
#  'ostrovsky-bednaja-nevesta_3_17_28': 0.014502731130436493,
#  'fonvizin-brigadir_134_9_19': 0.014506517206828232,
#  'mamin-sibirjak-zolotopromyshlenniki_131_25_27': 0.014520378125608486,
#  'ostrovsky-na-bojkom-meste_68_10_25': 0.01452753820948929,
#  'saltykov-shchedrin-smert-pazuhina_139_27_47': 0.01452936951429546,
#  'prutkov-chereposlov-sirech-frenolog_25_1_29': 0.014537963327566024,
#  'zagoskin-blagorodnyj-teatr_22_39_38': 0.014547753199241701,
#  'sollogub-chinovnik_88_2_38': 0.014559433214039554,
#  'ostrovsky-bednost-ne-porok_78_4_30': 0.014627622175659112,
#  'ostrovsky-vospitannica_177_18_23': 0.014630418687639367,
#  'petrov-ostrov-mira_130_45_15': 0.014646695776230926,
#  'kokoshkin-vospitanie_44_11_28': 0.014663001110604172,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_5_16': 0.014691376479709325,
#  'mamin-sibirjak-malenkaja-pravda_65_19_7': 0.014697825645672579,
#  'sumarokov-semira_93_5_9': 0.014700196485584774,
#  'babel-marija_205_3_75': 0.01470874367652642,
#  'gogol-zhenitba_11_12_66': 0.014713822633070984,
#  'shakhovskoy-urok-koketkam_176_18_20': 0.014887482481232091,
#  'sukhovo-kobylin-smert-tarelkina_40_9_11': 0.014907205958446341,
#  'kropotov-fomushka_12_28_3': 0.014919614986406555,
#  'plavilshchikov-sgovor-kutejkina_110_1_21': 0.014922340015800497,
#  'krylov-pirog_107_11_54': 0.01494052836963206,
#  'zagoskin-blagorodnyj-teatr_22_24_21': 0.014952180199479689,
#  'shakhovskoy-ne-lubo-ne-slushai_33_10_58': 0.0149835680352318,
#  'shakhovskoy-svoya-semya_146_0_37': 0.015010136917776681,
#  'sumarokov-artistona_97_11_3': 0.0150244355743927,
#  'knyazhnin-didona_196_34_3': 0.015024435797449448,
#  'saltykov-shchedrin-smert-pazuhina_139_19_75': 0.015049591903112045,
#  'ostrovsky-groza_147_41_15': 0.015059010324152312,
#  'turgenev-provintsialka_175_14_113': 0.015079768839923766,
#  'chekhov-tri-sestry_101_2_132': 0.01508390983208137,
#  'ostrovsky-goryachee-serdce_98_2_51': 0.015089427786442797,
#  'sukhovo-kobylin-delo_138_31_91': 0.015096395261060358,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_1_36': 0.015101918883280706,
#  'chekhov-leshii_71_20_18': 0.015111676253915308,
#  'sumarokov-pustaja-ssora_208_15_12': 0.015128025888956714,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_9_80': 0.015134464499371296,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_7_42': 0.015147989800718024,
#  'bulgakov-beg_190_6_139': 0.015165893512056496,
#  'ostrovsky-v-chuzhom-piru-pohmelje_144_16_19': 0.015176213662429522,
#  'sumarokov-rogonosets-po-voobrazheniju_100_11_23': 0.015186451248496345,
#  'fonvizin-vybor-guvernera_106_0_9': 0.015194093252593622,
#  'gogol-zhenitba_11_13_2': 0.015208448153425223,
#  'ekaterina-vtoraja-iz-zhizni-rjurika_188_13_2': 0.015208448153425223,
#  'fonvizin-brigadir_134_24_45': 0.015210844951654107,
#  'sukhovo-kobylin-svadba-krechinskogo_55_6_19': 0.015237567368157588,
#  'krylov-urok-dochkam_198_0_75': 0.015301368430363484,
#  'ostrovsky-volki-i-ovtsy_129_3_27': 0.015329823507214917,
#  'sumarokov-chudovischi_121_16_24': 0.01533285740558021,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_1_64': 0.015354099103764509,
#  'kheraskov-osvobozhdennaja-moskva_203_20_28': 0.015359506620673046,
#  'sumarokov-pustaja-ssora_208_2_17': 0.015377476373322296,
#  'sumarokov-dimitrij-samozvanets_84_32_2': 0.015393700962975633,
#  'mamin-sibirjak-malenkaja-pravda_65_25_11': 0.01539587009736442,
#  'ostrovsky-neozhidannyj-sluchaj_189_6_53': 0.015400323848189165,
#  'tolstoy-zhivoy-trup_89_45_16': 0.015404495849891328,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_8_41': 0.01540922055534696,
#  'sudovshchikov-neslyhannoe-divo_114_48_19': 0.01541459632627273,
#  'tolstoy-tsar-boris_201_4_124': 0.015417328766288287,
#  'pisarev-lukavin_158_30_58': 0.015436041810375174,
#  'sumarokov-rogonosets-po-voobrazheniju_100_12_26': 0.015443757574757128,
#  'krylov-filomela_161_27_7': 0.01547765945421695,
#  'nekrasov-junost-lomonosova_59_0_44': 0.0155090586648878,
#  'petrov-ostrov-mira_130_12_8': 0.015515338541352902,
#  'ostrovsky-goryachee-serdce_98_11_126': 0.015517882043039598,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_1_61': 0.015523175930598888,
#  'lazhechnikov-okopirovalsya_153_3_17': 0.015540680361826278,
#  'babel-marija_205_0_89': 0.015541985045417117,
#  'bulgakov-zojkina-kvartira_35_0_401': 0.015552018410591362,
#  'ostrovsky-groza_147_31_32': 0.015568266292639943,
#  'kokoshkin-vospitanie_44_25_96': 0.015574904364033765,
#  'ostrovsky-ne-soshlis-harakterami_181_6_76': 0.015592099014341238,
#  'pushkin-kamenniy-gost_60_3_69': 0.015600221033185029,
#  'mamin-sibirjak-malenkaja-pravda_65_51_15': 0.015602676799208265,
#  'petrov-ostrov-mira_130_61_3': 0.01561883739954371,
#  'ostrovsky-les_90_37_46': 0.015635948602582123,
#  'ostrovsky-pozdnyaya-lyubov_52_26_41': 0.015638606741198824,
#  'ostrovsky-ne-v-svoi-sani-ne-sadis_47_30_30': 0.01564569353958828,
#  'pisemskij-gorkaja-sudbina_105_17_5': 0.015655041660939843,
#  'ostrovsky-goryachee-serdce_98_35_44': 0.015670542512283836,
#  'gorky-vassa-zheleznova_64_1_316': 0.015672497468535364,
#  'ostrovsky-ne-ot-mira-sego_172_19_22': 0.015678787587636144,
#  'krylov-prokazniki_142_17_21': 0.01568759398194729,
#  'tolstoy-smert-ioanna-groznogo_145_2_103': 0.01568957628120819,
#  'gogol-igroki_160_15_61': 0.01569366256478278,
#  'ostrovsky-bednost-ne-porok_78_5_16': 0.015699242707045886,
#  'lermontov-maskarad_193_7_67': 0.015714976622139987,
#  'tolstoy-tsar-fedor-ioannovich_143_6_35': 0.01571668349762896,
#  'krylov-amerikantsy_192_0_48': 0.015717898465787635,
#  'ostrovsky-poslednyaya-zhertva_125_21_76': 0.015729702965096324,
#  'shakhovskoy-svoya-semya_146_5_105': 0.015748889999029108,
#  'knyazhnin-traur_103_5_72': 0.015782683479034765,
#  'ostrovsky-tyazhelye-dni_200_10_40': 0.015790722178198085,
#  'gogol-revizor_23_43_16': 0.015797154686548836,
#  'ostrovsky-shutniki_120_12_45': 0.015813891524221458,
#  'ostrovsky-bez-viny-vinovatye_53_18_31': 0.015820319016089275,
#  'gorky-vassa-zheleznova_64_2_346': 0.015850872700189506,
#  'andreyev-mysl_14_2_124': 0.01585844887604875,
#  'ekaterina-vtoraja-o-vremja_179_16_32': 0.01587109345948334,
#  'shakhovskoy-urok-koketkam_176_27_24': 0.01588254344709575,
#  'tolstoy-vlast-tmy_183_12_20': 0.015890677186288685,
#  'gogol-revizor_23_9_15': 0.01590127563301452,
#  'griboyedov-gore-ot-uma_102_17_20': 0.01591401345895872,
#  'ostrovsky-svoi-ljudi_128_30_20': 0.01591663809907401,
#  'babel-marija_205_1_118': 0.015918929530778815,
#  'ekaterina-vtoraja-o-vremja_179_17_18': 0.01594898479122621,
#  'khmelnitsky-vzaimnye-ispytaniya_17_13_19': 0.01595302724803904,
#  'lazhechnikov-okopirovalsya_153_14_113': 0.01595992852859419,
#  'bulgakov-vojna-i-mir_69_5_34': 0.015974993780305886,
#  'ostrovsky-nevolnicy_162_16_59': 0.015979549842164827,
#  'turgenev-provintsialka_175_22_40': 0.016006477934264723,
#  'ostrovsky-ne-v-svoi-sani-ne-sadis_47_32_22': 0.01603023937096879,
#  'pisemskij-gorkaja-sudbina_105_3_20': 0.016035348012965304,
#  'pisemskij-gorkaja-sudbina_105_20_22': 0.016058656250117733,
#  'ostrovsky-bez-viny-vinovatye_53_7_77': 0.016110521920357408,
#  'mayakovsky-banja_115_4_101': 0.01613160348073262,
#  'shakhovskoy-urok-koketkam_176_33_53': 0.016131814035478267,
#  'ostrovsky-les_90_20_21': 0.016139670573888692,
#  'khmelnitsky-svetskiy-sluchay_164_4_73': 0.016157924209398655,
#  'ostrovsky-ne-v-svoi-sani-ne-sadis_47_27_8': 0.01616413421189029,
#  'gogol-zhenitba_11_25_26': 0.01616793362796708,
#  'krylov-prokazniki_142_11_12': 0.016202677041148784,
#  'ostrovsky-ne-v-svoi-sani-ne-sadis_47_2_45': 0.01623287445398237,
#  'chekhov-leshii_71_43_56': 0.016288343545079673,
#  'prutkov-chereposlov-sirech-frenolog_25_0_29': 0.016298310174394526,
#  'belsky-skazanie-o-nevidimom-grade-kitezhe_186_2_99': 0.016323186688237297,
#  'saltykov-shchedrin-smert-pazuhina_139_31_49': 0.0163338085758009,
#  'ostrovsky-shutniki_120_17_33': 0.01633870605119974,
#  'tolstoy-vlast-tmy_183_10_38': 0.01635222336954961,
#  'ostrovsky-bednaja-nevesta_3_8_15': 0.016376662320108842,
#  'chekhov-leshii_71_15_17': 0.016428551548378974,
#  'ozerov-dmitrij-donskoj_159_10_3': 0.01645975390435298,
#  'fonvizin-nedorosl_149_29_35': 0.01647484977427958,
#  'ostrovsky-svoi-sobaki-gryzutsya-chuzhaya-ne-pristavaj_13_3_22': 0.016563159906750065,
#  'sukhovo-kobylin-smert-tarelkina_40_19_28': 0.016564193433710364,
#  'ostrovsky-les_90_15_38': 0.016597971975034487,
#  'gorky-vassa-zheleznova_64_0_403': 0.016611263226100022,
#  'andreyev-k-zvezdam_150_3_155': 0.01662867767400703,
#  'ostrovsky-vospitannica_177_12_21': 0.01665271258107222,
#  'glinka-velzen_36_16_13': 0.016671302149994176,
#  'gogol-lakeiskaja_0_3_10': 0.01667247091000669,
#  'tolstoy-zhivoy-trup_89_48_24': 0.016674570135308295,
#  'ostrovsky-ne-tak-zhivi-kak-hochetsya_75_26_38': 0.016685370423978732,
#  'kedrin-rembrandt_79_25_25': 0.01668603025173237,
#  'gogol-otryvok_118_0_65': 0.016689088800235077,
#  'sukhovo-kobylin-smert-tarelkina_40_22_111': 0.016704327146665036,
#  'griboyedov-gore-ot-uma_102_37_9': 0.016706741485005748,
#  'kapnist-antigona_109_6_4': 0.016717066909100794,
#  'tolstoy-zhivoy-trup_89_4_11': 0.01675748680492474,
#  'knyazhnin-chudaki_199_24_11': 0.016784445634942056,
#  'andreyev-k-zvezdam_150_2_247': 0.016798231373891418,
#  'ostrovsky-goryachee-serdce_98_15_21': 0.016807517962334786,
#  'ostrovsky-bespridannitsa_83_22_16': 0.016818117841497296,
#  'kedrin-rembrandt_79_18_29': 0.01681885522380145,
#  'gogol-igroki_160_24_29': 0.0168366749051214,
#  'lazhechnikov-okopirovalsya_153_21_23': 0.01686114711274741,
#  'pushkin-boris-godunov_37_6_80': 0.016872952698670726,
#  'krylov-prokazniki_142_51_23': 0.016880456752044765,
#  'nikolev-samolyubivyj-stihotvorec_20_24_25': 0.016886901436832576,
#  'ozerov-dmitrij-donskoj_159_21_10': 0.016893828823104202,
#  'pisarev-lukavin_158_0_50': 0.016920928856579615,
#  'chekhov-chaika_49_3_192': 0.016945785559232852,
#  'ostrovsky-bednost-ne-porok_78_13_27': 0.016948537253184695,
#  'zagoskin-blagorodnyj-teatr_22_19_30': 0.016973852271172235,
#  'tolstoy-vlast-tmy_183_63_10': 0.017013977125515722,
#  'kheraskov-plamena_191_15_7': 0.01701934319652838,
#  'ostrovsky-pozdnyaya-lyubov_52_2_56': 0.017021950268203332,
#  'ostrovsky-poslednyaya-zhertva_125_14_9': 0.017023200220669277,
#  'ostrovsky-beshenye-dengi_91_34_40': 0.01703111025074055,
#  'ostrovsky-ne-v-svoi-sani-ne-sadis_47_20_35': 0.017083489936747045,
#  'krylov-prokazniki_142_24_12': 0.01708631408384385,
#  'krylov-podschipa-ili-trumf_58_7_14': 0.01708793416849311,
#  'turgenev-gde-tonko-tam-i-rvetsja_195_0_481': 0.017119883960433936,
#  'knyazhnin-hvastun_180_1_73': 0.017128484463703308,
#  'ostrovsky-bednost-ne-porok_78_19_14': 0.017130707871744,
#  'fonvizin-korion_21_9_9': 0.0171893727012815,
#  'petrov-ostrov-mira_130_29_26': 0.017200160894990574,
#  'chekhov-ivanov_169_8_21': 0.01726389736076814,
#  'ostrovsky-pozdnyaya-lyubov_52_28_36': 0.01727935958371765,
#  'khmelnitsky-govorun_119_0_14': 0.017304165421919555,
#  'ostrovsky-beshenye-dengi_91_2_37': 0.01731203112086063,
#  'tolstoy-vlast-tmy_183_86_19': 0.01735806389917687,
#  'ostrovsky-v-chuzhom-piru-pohmelje_144_0_36': 0.017358944056624432,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_15_25': 0.017360889702195518,
#  'ostrovsky-puchina_50_10_13': 0.017360994429690593,
#  'tolstoy-tsar-boris_201_1_43': 0.017371125479445026,
#  'chekhov-ivanov_169_25_22': 0.01737189595863683,
#  'griboyedov-gore-ot-uma_102_24_9': 0.01737453501206189,
#  'ostrovsky-shutniki_120_28_18': 0.01738267988538559,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_37_56': 0.01739063575898256,
#  'sumarokov-rogonosets-po-voobrazheniju_100_7_12': 0.017396520106023414,
#  'mamin-sibirjak-zolotopromyshlenniki_131_38_7': 0.017427656001772495,
#  'tolstoy-vlast-tmy_183_52_9': 0.01744771499814585,
#  'sumarokov-vzdorschitsa_48_20_11': 0.017500370523968824,
#  'knyazhnin-olga_41_17_11': 0.01750809661520843,
#  'ostrovsky-nevolnicy_162_8_82': 0.01753135108731913,
#  'lermontov-maskarad_193_0_99': 0.017536514420400755,
#  'gorky-egor-bulychov-i-drugie_62_1_443': 0.01755644808351577,
#  'knyazhnin-hvastun_180_48_39': 0.017566556064044465,
#  'kokoshkin-vospitanie_44_13_28': 0.01758973346253448,
#  'shakhovskoy-ne-lubo-ne-slushai_33_3_15': 0.017596315932552654,
#  'ostrovsky-svoi-ljudi_128_33_77': 0.017615669275796112,
#  'sukhovo-kobylin-delo_138_13_100': 0.017617590818914976,
#  'tolstoy-vlast-tmy_183_38_18': 0.01762506822546578,
#  'merezhkovsky-pavel-pervyj_185_4_242': 0.017640623569951,
#  'sudovshchikov-neslyhannoe-divo_114_34_24': 0.017654915929205806,
#  'ostrovsky-na-bojkom-meste_68_8_34': 0.017665110970897985,
#  'mamin-sibirjak-malenkaja-pravda_65_20_18': 0.017670401189910596,
#  'ostrovsky-groza_147_35_12': 0.017698839532777205,
#  'kropotov-fomushka_12_30_3': 0.017723488576335517,
#  'knyazhnin-didona_196_26_3': 0.017723488576335517,
#  'tolstoy-tsar-boris_201_2_80': 0.017759831646566825,
#  'ostrovsky-bednaja-nevesta_3_30_39': 0.017764144759596746,
#  'gogol-igroki_160_11_16': 0.017764433562020995,
#  'turgenev-provintsialka_175_6_8': 0.017774342480225722,
#  'ostrovsky-shutniki_120_23_9': 0.017795869895455715,
#  'sumarokov-semira_93_1_9': 0.017817346110209346,
#  'gogol-revizor_23_21_40': 0.017843092303291928,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_33_19': 0.017860123581596894,
#  'ostrovsky-pozdnyaya-lyubov_52_22_32': 0.017924255621770035,
#  'ostrovsky-v-chuzhom-piru-pohmelje_144_17_41': 0.017930167673752998,
#  'leskov-rastochitel_61_58_21': 0.01795746788425968,
#  'ostrovsky-pozdnyaya-lyubov_52_8_13': 0.017990860034067906,
#  'lomonosov-demofont_80_7_6': 0.018008374225916703,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_16_37': 0.018038893300809027,
#  'mamin-sibirjak-zolotopromyshlenniki_131_12_7': 0.018049487664710977,
#  'ostrovsky-prazdnichnyj-son-do-obeda_207_3_70': 0.018057607034512715,
#  'lermontov-menschen-und-leidenschaften_92_1_4': 0.0180629129104357,
#  'sumarokov-artistona_97_3_5': 0.01806525118847073,
#  'leskov-rastochitel_61_56_3': 0.018127007639635394,
#  'kheraskov-plamena_191_16_28': 0.018129531316990573,
#  'sukhovo-kobylin-delo_138_40_64': 0.018132954335984653,
#  'sumarokov-chudovischi_121_18_5': 0.01823501473042154,
#  'ostrovsky-dohodnoe-mesto_124_19_44': 0.018240127577760168,
#  'ostrovsky-tyazhelye-dni_200_5_11': 0.018242986175401044,
#  'knyazhnin-hvastun_180_49_20': 0.018311477880572222,
#  'mamin-sibirjak-zolotopromyshlenniki_131_34_17': 0.01832257687960248,
#  'shakhovskoy-urok-koketkam_176_20_69': 0.01834415291849036,
#  'sumarokov-dimitrij-samozvanets_84_0_28': 0.018344392094330714,
#  'khmelnitsky-vozdushnye-zamki_165_2_27': 0.018346636297617503,
#  'knyazhnin-didona_196_15_2': 0.0183496635025787,
#  'knyazhnin-hvastun_180_28_73': 0.018406875159102873,
#  'gogol-revizor_23_11_31': 0.018420728464751374,
#  'bulgakov-dni-turbinyh_46_1_277': 0.01842680943005902,
#  'sumarokov-vzdorschitsa_48_18_13': 0.01843527583922217,
#  'ostrovsky-volki-i-ovtsy_129_25_9': 0.018444991921290285,
#  'krylov-podschipa-ili-trumf_58_18_8': 0.01844637798853823,
#  'shakhovskoy-pustodomy_56_6_30': 0.018456773558386548,
#  'ostrovsky-poslednyaya-zhertva_125_48_36': 0.018460152902834478,
#  'knyazhnin-didona_196_3_22': 0.01846456484385298,
#  'pisarev-lukavin_158_4_21': 0.018511069255982525,
#  'kedrin-rembrandt_79_34_10': 0.018514332392481056,
#  'sukhovo-kobylin-delo_138_18_24': 0.018515072537783495,
#  'pisarev-naslednica_54_9_21': 0.018570834851547556,
#  'bulgakov-beg_190_3_98': 0.018576099239659506,
#  'knyazhnin-hvastun_180_12_17': 0.018641088749653062,
#  'sumarokov-tresotinius_122_10_5': 0.018646357026171116,
#  'rostopchina-neludimka_7_5_19': 0.018654946086005347,
#  'ostrovsky-shutniki_120_24_15': 0.018688908376021156,
#  'kokoshkin-vospitanie_44_27_33': 0.01870087599771818,
#  'ostrovsky-trudovoj-hleb_16_25_12': 0.01870654062455191,
#  'nikolev-samolyubivyj-stihotvorec_20_17_26': 0.018738247022788236,
#  'chekhov-djadja-vanja_136_2_148': 0.018768809844301466,
#  'fonvizin-brigadir_134_12_25': 0.018787041362039757,
#  'ostrovsky-groza_147_26_43': 0.018798307616646755,
#  'tolstoy-vlast-tmy_183_34_23': 0.018862513938089253,
#  'ostrovsky-volki-i-ovtsy_129_46_54': 0.018867040291041144,
#  'turgenev-holostjak_15_0_313': 0.018905915837059153,
#  'pushkin-kamenniy-gost_60_2_73': 0.01890752425163672,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_4_53': 0.01890772885319577,
#  'kokoshkin-vospitanie_44_24_61': 0.01891689925849484,
#  'lermontov-menschen-und-leidenschaften_92_31_36': 0.018947317041867556,
#  'sumarokov-semira_93_18_26': 0.018953431877666037,
#  'tolstoy-tsar-fedor-ioannovich_143_7_109': 0.018994642706183205,
#  'chekhov-vishnevyi-sad_87_1_157': 0.019060906614674227,
#  'sukhovo-kobylin-svadba-krechinskogo_55_39_58': 0.019081952366638094,
#  'glinka-velzen_36_13_7': 0.019102442622626743,
#  'khmelnitsky-vozdushnye-zamki_165_9_9': 0.019106926923239835,
#  'tolstoy-vlast-tmy_183_42_4': 0.01912871340086347,
#  'majkov-femist-i-ieronima_133_19_13': 0.019143631355220656,
#  'tolstoy-tsar-fedor-ioannovich_143_2_173': 0.019167932480122753,
#  'zagoskin-blagorodnyj-teatr_22_15_11': 0.01919735551169502,
#  'bulgakov-dni-turbinyh_46_6_234': 0.019199043609266112,
#  'gogol-igroki_160_21_16': 0.019205816461785416,
#  'chekhov-vishnevyi-sad_87_3_126': 0.01923200106642444,
#  'chekhov-medved_95_0_11': 0.019251547744663835,
#  'nekrasov-shila-v-meshke-ne-utaish_148_6_22': 0.01930489300468341,
#  'sumarokov-artistona_97_19_20': 0.019328386837584026,
#  'rostopchina-neludimka_7_17_14': 0.019328457946021053,
#  'sumarokov-opekun_2_11_39': 0.01934355852914548,
#  'blok-neznakomka_6_2_55': 0.01934842965811638,
#  'knyazhnin-didona_196_1_14': 0.01934987915341076,
#  'chekhov-leshii_71_45_13': 0.019363000078499174,
#  'ostrovsky-nevolnicy_162_6_15': 0.019376782611390076,
#  'ostrovsky-bez-viny-vinovatye_53_13_42': 0.019403805521779147,
#  'kokoshkin-vospitanie_44_23_14': 0.019409892179887693,
#  'majkov-agriopa_19_2_5': 0.019430286017426038,
#  'ostrovsky-puchina_50_9_34': 0.019456092847019275,
#  'chekhov-ivanov_169_33_18': 0.019460599884258214,
#  'kheraskov-plamena_191_22_13': 0.019463935386171333,
#  'turgenev-provintsialka_175_18_38': 0.01948969762849812,
#  'chekhov-chaika_49_1_120': 0.019495103595644943,
#  'ostrovsky-dohodnoe-mesto_124_8_20': 0.019505026624482013,
#  'ostrovsky-na-bojkom-meste_68_11_8': 0.019505777759035125,
#  'tolstoy-vlast-tmy_183_27_30': 0.019512122747876344,
#  'knyazhnin-neudachnyj-primiritel_117_12_15': 0.019531455678793254,
#  'kapnist-yabeda_132_40_12': 0.019546077708050648,
#  'ostrovsky-bespridannitsa_83_14_49': 0.0195630321348863,
#  'rostopchina-neludimka_7_9_28': 0.019580248650410276,
#  'bulgakov-beg_190_7_75': 0.019597754792793746,
#  'ostrovsky-vospitannica_177_0_17': 0.019600442298708554,
#  'ostrovsky-greh-da-beda-na-kogo-ne-zhivet_45_32_22': 0.01963366281522912,
#  'ostrovsky-bednost-ne-porok_78_12_9': 0.019638279014494563,
#  'gumilyov-gondla_70_12_16': 0.01966752073553778,
#  'tolstoy-smert-ioanna-groznogo_145_3_243': 0.019670160236908988,
#  'kapnist-yabeda_132_33_8': 0.019701591972901975,
#  'gogol-revizor_23_52_0': 0.019712905941245907,
#  'sukhovo-kobylin-svadba-krechinskogo_55_32_0': 0.019712905941245907,
#  'tolstoy-zhivoy-trup_89_0_0': 0.019712905941245907,
#  'tolstoy-zhivoy-trup_89_26_0': 0.019712905941245907,
#  'tolstoy-zhivoy-trup_89_38_0': 0.019712905941245907,
#  'tolstoy-zhivoy-trup_89_47_0': 0.019712905941245907,
#  'fonvizin-vybor-guvernera_106_6_0': 0.019712905941245907,
#  'ostrovsky-volki-i-ovtsy_129_2_0': 0.019712905941245907,
#  'petrov-ostrov-mira_130_31_0': 0.019712905941245907,
#  'plavilshchikov-sgovor-kutejkina_110_7_62': 0.01971444991325584,
#  'sumarokov-ssora-u-muzha-s-zhenoj_206_20_17': 0.019721611277968603,
#  'tolstoy-vlast-tmy_183_87_15': 0.019723040125617517,
#  'ostrovsky-bespridannitsa_83_5_38': 0.019729000788815818,
#  'tolstoy-vlast-tmy_183_45_15': 0.01976022523528983,
#  'ostrovsky-beshenye-dengi_91_31_22': 0.019765598195068835,
#  'ostrovsky-goryachee-serdce_98_1_57': 0.01976664465579769,
#  'chekhov-ivanov_169_20_27': 0.01976674492569535,
#  'ostrovsky-poslednyaya-zhertva_125_36_22': 0.019768796748327946,
#  'merezhkovsky-pavel-pervyj_185_3_305': 0.019776381866982957,
#  'ostrovsky-ne-tak-zhivi-kak-hochetsya_75_6_5': 0.019788102547513873,
#  'ostrovsky-prazdnichnyj-son-do-obeda_207_10_10': 0.01979096501011925,
#  'ostrovsky-trudovoj-hleb_16_4_25': 0.01981326221289426,
#  'ostrovsky-dohodnoe-mesto_124_7_38': 0.01981959067374334,
#  'ostrovsky-bogatye-nevesty_184_9_48': 0.01984130083510039,
#  'nekrasov-shila-v-meshke-ne-utaish_148_15_56': 0.019855885496654502,
#  'krylov-modnaja-lavka_197_28_17': 0.019867881108477155,
#  'gogol-revizor_23_37_22': 0.019868113742922827,
#  'griboyedov-molodye-suprugi_157_7_33': 0.019881322725982652,
#  'ostrovsky-volki-i-ovtsy_129_32_9': 0.01989137619447402,
#  'ostrovsky-svoi-ljudi_128_2_17': 0.01991902644875203,
#  'ostrovsky-volki-i-ovtsy_129_42_22': 0.019926961058812545,
#  'petrov-ostrov-mira_130_19_56': 0.01997194630109701,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_17_63': 0.019985482199581107,
#  'ostrovsky-vospitannica_177_19_31': 0.01998905780071972,
#  'ostrovsky-volki-i-ovtsy_129_15_16': 0.020001985208550774,
#  'ostrovsky-les_90_12_19': 0.020007304572263355,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_22_27': 0.020011977544883153,
#  'ostrovsky-poslednyaya-zhertva_125_9_59': 0.02001562107685949,
#  'sumarokov-rogonosets-po-voobrazheniju_100_3_24': 0.02002710058983896,
#  'lomonosov-tamira-i-selim_51_9_5': 0.02004993759217816,
#  'tolstoy-tsar-boris_201_9_39': 0.0200586606022593,
#  'ostrovsky-shutniki_120_10_25': 0.02006993455601286,
#  'ostrovsky-vospitannica_177_20_44': 0.020086777682564807,
#  'chekhov-leshii_71_31_6': 0.020090495602523593,
#  'sumarokov-chudovischi_121_2_19': 0.020092808192559996,
#  'zagoskin-blagorodnyj-teatr_22_33_18': 0.020100411457536986,
#  'ostrovsky-groza_147_32_19': 0.020150982872963283,
#  'ostrovsky-beshenye-dengi_91_6_11': 0.02015596645144431,
#  'ostrovsky-nevolnicy_162_31_65': 0.02016397614916626,
#  'ostrovsky-les_90_2_18': 0.020169390769962593,
#  'ostrovsky-snegurochka_152_22_5': 0.020174166825936195,
#  'sumarokov-dimitrij-samozvanets_84_4_17': 0.02018258478524376,
#  'ostrovsky-goryachee-serdce_98_23_19': 0.02021562991271502,
#  'ostrovsky-na-bojkom-meste_68_26_53': 0.020267420645424982,
#  'ostrovsky-nevolnicy_162_27_39': 0.02027295221453178,
#  'gogol-igroki_160_17_32': 0.020273434910413793,
#  'pisarev-lukavin_158_32_9': 0.02027808954471174,
#  'shakhovskoy-urok-koketkam_176_10_12': 0.02027843748262431,
#  'ostrovsky-les_90_34_52': 0.020300865592681266,
#  'kheraskov-venecianskaya-monahinya_167_16_18': 0.020322840919776212,
#  'sumarokov-vzdorschitsa_48_22_18': 0.020359761058511484,
#  'gogol-zhenitba_11_26_18': 0.020368017987637467,
#  'ostrovsky-trudovoj-hleb_16_7_32': 0.02038173983509918,
#  'khmelnitsky-vozdushnye-zamki_165_4_32': 0.020406052366569193,
#  'kheraskov-venecianskaya-monahinya_167_10_47': 0.020408951888845343,
#  'sumarokov-sinav-i-truvor_209_0_21': 0.020415348237580285,
#  'ostrovsky-trudovoj-hleb_16_16_18': 0.020422180700556642,
#  'ozerov-dmitrij-donskoj_159_9_19': 0.020424717787590967,
#  'kedrin-rembrandt_79_29_34': 0.020440447082566992,
#  'saltykov-shchedrin-smert-pazuhina_139_2_38': 0.020445632854739885,
#  'shakhovskoy-pustodomy_56_8_23': 0.02044710639289146,
#  'ostrovsky-groza_147_12_29': 0.020463811424316445,
#  'ostrovsky-bespridannitsa_83_6_45': 0.020483342829270994,
#  'sukhovo-kobylin-svadba-krechinskogo_55_18_26': 0.020490359292875952,
#  'tolstoy-tsar-boris_201_6_60': 0.020491575306872293,
#  'ostrovsky-beshenye-dengi_91_11_42': 0.020497343519851472,
#  'sollogub-chinovnik_88_10_34': 0.020557703749449117,
#  'rostopchina-neludimka_7_2_72': 0.02056166511606682,
#  'lomonosov-tamira-i-selim_51_26_14': 0.020568550602100954,
#  'ostrovsky-ne-ot-mira-sego_172_2_48': 0.02056995539010888,
#  'knyazhnin-chudaki_199_29_11': 0.020579746799220918,
#  'ostrovsky-tyazhelye-dni_200_8_53': 0.020599580676248223,
#  'sumarokov-rogonosets-po-voobrazheniju_100_26_10': 0.020623029461429937,
#  'ostrovsky-bogatye-nevesty_184_23_63': 0.02063104651965168,
#  'lensky-horosha-i-durna_112_19_54': 0.020638059037835547,
#  'dashkova-toisiokov_73_16_10': 0.02064648751774339,
#  'prutkov-fantaziya_1_9_70': 0.020653280503674286,
#  'ostrovsky-trudovoj-hleb_16_20_38': 0.02066663417467686,
#  'gogol-igroki_160_4_21': 0.020722279194497643,
#  'fonvizin-nedorosl_149_13_29': 0.020751968448208754,
#  'knyazhnin-rosslav_10_27_3': 0.020775961196147136,
#  'afinogenov-mashenka_178_4_111': 0.020804601058769037,
#  'bulgakov-ivan-vasilevich_171_1_245': 0.020831682616546426,
#  'sollogub-chinovnik_88_17_14': 0.020833397066412185,
#  'khmelnitsky-svetskiy-sluchay_164_8_37': 0.02089090601101697,
#  'gumilyov-gondla_70_6_10': 0.020898255230347104,
#  'ekaterina-vtoraja-o-vremja_179_7_9': 0.020902583722462363,
#  'lermontov-menschen-und-leidenschaften_92_24_29': 0.020904701474861526,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_3_74': 0.020914717720481913,
#  'bulgakov-vojna-i-mir_69_9_12': 0.02091634443131434,
#  'fonvizin-brigadir_134_15_24': 0.020917036301833822,
#  'pisarev-poezdka-v-kronshtadt_182_23_3': 0.02092784511024879,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_9_11': 0.02093418354993238,
#  'sumarokov-tresotinius_122_7_15': 0.020991352249789527,
#  'lermontov-maskarad_193_4_73': 0.020993558395589234,
#  'saltykov-shchedrin-smert-pazuhina_139_20_38': 0.02099437207333455,
#  'sudovshchikov-neslyhannoe-divo_114_10_15': 0.02100499445030879,
#  'kedrin-rembrandt_79_20_10': 0.021011447529027068,
#  'sumarokov-pustaja-ssora_208_4_10': 0.021066439495064572,
#  'kapnist-yabeda_132_13_49': 0.02108478904879485,
#  'kokoshkin-vospitanie_44_15_57': 0.0210942919422969,
#  'knyazhnin-hvastun_180_47_14': 0.021099968772679306,
#  'krylov-prokazniki_142_4_20': 0.021109215446670337,
#  'afinogenov-mashenka_178_0_104': 0.02113609041908451,
#  'knyazhnin-olga_41_5_23': 0.021161123906042297,
#  'ostrovsky-goryachee-serdce_98_30_41': 0.021168460114669094,
#  'bulgakov-poloumnyj-zhurden_137_0_283': 0.02118563328169669,
#  'ostrovsky-les_90_8_45': 0.02119459261671183,
#  'ostrovsky-puchina_50_5_50': 0.021198616345072918,
#  'pushkin-kamenniy-gost_60_0_52': 0.021200929929709133,
#  'nikolev-samolyubivyj-stihotvorec_20_32_42': 0.021215357394688703,
#  'lermontov-strannyj-chelovek_39_11_149': 0.021224759717007047,
#  'ostrovsky-volki-i-ovtsy_129_9_43': 0.021229410357213388,
#  'krylov-prokazniki_142_29_18': 0.021234869861495143,
#  'ostrovsky-snegurochka_152_15_22': 0.02124309633945375,
#  'shakhovskoy-pustodomy_56_19_52': 0.021244865263702,
#  'sudovshchikov-neslyhannoe-divo_114_46_33': 0.0212831426922673,
#  'ostrovsky-za-chem-pojdesh-to-i-najdesh_123_2_38': 0.02131099205272244,
#  'sumarokov-semira_93_25_6': 0.02131370633273173,
#  'knyazhnin-didona_196_12_18': 0.021339233963266264,
#  'ostrovsky-vospitannica_177_3_29': 0.021340049244575096,
#  'ostrovsky-bednost-ne-porok_78_2_18': 0.021356542771281416,
#  'ostrovsky-shutniki_120_15_7': 0.021364279632236298,
#  'sumarokov-vzdorschitsa_48_19_15': 0.021391118219444602,
#  'sumarokov-artistona_97_0_20': 0.021407214883292332,
#  'mamin-sibirjak-malenkaja-pravda_65_13_7': 0.021420889972932365,
#  'knyazhnin-neudachnyj-primiritel_117_20_42': 0.021423754072803926,
#  'ostrovsky-shutniki_120_18_68': 0.02144409457376582,
#  'chekhov-leshii_71_29_37': 0.021444326785700733,
#  'leskov-rastochitel_61_12_73': 0.021454208264766426,
#  'ostrovsky-bogatye-nevesty_184_22_32': 0.02146285440711062,
#  'ostrovsky-svoi-ljudi_128_8_21': 0.021472250656503163,
#  'ostrovsky-tyazhelye-dni_200_7_7': 0.021472706528020507,
#  'kropotov-fomushka_12_18_8': 0.02148190525311318,
#  'ostrovsky-staryj-drug-luchshe-novyh-dvuh_163_9_34': 0.02148244497733583,
#  'bulgakov-batum_111_1_274': 0.021493510970628557,
#  'plavilshchikov-sgovor-kutejkina_110_3_34': 0.02150286803615313,
#  'lazhechnikov-okopirovalsya_153_12_40': 0.021515026753510726,
#  'ostrovsky-bednost-ne-porok_78_25_16': 0.021517157868414672,
#  'sumarokov-vzdorschitsa_48_29_38': 0.021522137388036672,
#  'krylov-modnaja-lavka_197_23_24': 0.02153793822525327,
#  'afinogenov-mashenka_178_5_79': 0.021564429136963853,
#  'babel-zakat_135_2_112': 0.021601081008116255,
#  'kokoshkin-vospitanie_44_5_60': 0.02161097548041763,
#  'ostrovsky-snegurochka_152_3_28': 0.02161461654444001,
#  'knyazhnin-hvastun_180_2_16': 0.021622695820549105,
#  'nikolev-samolyubivyj-stihotvorec_20_5_27': 0.021625490620131152,
#  'ostrovsky-volki-i-ovtsy_129_22_60': 0.021633351716621937,
#  'gogol-revizor_23_23_9': 0.021634452627032664,
#  'knyazhnin-chudaki_199_42_24': 0.02164559673700844,
#  'knyazhnin-chudaki_199_10_19': 0.02164707264035618,
#  'ostrovsky-bespridannitsa_83_20_14': 0.021647135388606274,
#  'ostrovsky-bespridannitsa_83_16_30': 0.021671295845461985,
#  'ostrovsky-goryachee-serdce_98_18_64': 0.02167595578520142,
#  'mayakovsky-misteriya-buff_116_0_122': 0.0216784549786626,
#  'ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij_77_11_68': 0.021692173100010065,
#  'babel-zakat_135_5_70': 0.02170146994842611,
#  'ostrovsky-svoi-sobaki-gryzutsya-chuzhaya-ne-pristavaj_13_1_20': 0.0217127193873552,
#  'knyazhnin-neudachnyj-primiritel_117_2_98': 0.021717507966591883,
#  'knyazhnin-rosslav_10_11_17': 0.021735085771360487,
#  'ostrovsky-dohodnoe-mesto_124_22_18': 0.021738901654351588,
#  'ostrovsky-beshenye-dengi_91_18_49': 0.021740723451071788,
#  'ostrovsky-volki-i-ovtsy_129_19_84': 0.021800465648148384,
#  'kedrin-rembrandt_79_10_29': 0.021813830162191954,
#  'ostrovsky-groza_147_1_5': 0.02183464101184346,
#  'sumarokov-artistona_97_26_28': 0.021844667678526476,
#  'ostrovsky-groza_147_34_11': 0.021854443804525656,
#  'bulgakov-vojna-i-mir_69_15_30': 0.021879351286691183,
#  'saltykov-shchedrin-smert-pazuhina_139_6_12': 0.02189376386427835,
#  'ostrovsky-les_90_23_20': 0.021905913916192576,
#  'sollogub-chinovnik_88_16_6': 0.021934536805273016,
#  'shakhovskoy-svoya-semya_146_19_94': 0.021949872927228588,
#  'kheraskov-osvobozhdennaja-moskva_203_29_7': 0.022015030469156958,
#  'lensky-horosha-i-durna_112_1_44': 0.022015745069297876,
#  'bulgakov-beg_190_4_69': 0.02204554956404044,
#  'gogol-igroki_160_7_126': 0.0220508494015765,
#  'ekaterina-vtoraja-iz-zhizni-rjurika_188_0_5': 0.022092113198565112,
#  'babel-zakat_135_7_100': 0.022093555971429476,
#  'ostrovsky-puchina_50_20_42': 0.022116700885262297,
#  'tolstoy-tsar-fedor-ioannovich_143_3_173': 0.022128745998506564,
#  'sudovshchikov-neslyhannoe-divo_114_20_35': 0.022180848621367003,
#  'ostrovsky-goryachee-serdce_98_16_29': 0.022184498510520304,
#  'gumilyov-gondla_70_18_12': 0.02219461418473715,
#  'khmelnitsky-svetskiy-sluchay_164_1_36': 0.022195410442635673,
#  'ostrovsky-tyazhelye-dni_200_6_87': 0.022221768206635736,
#  'saltykov-shchedrin-smert-pazuhina_139_32_17': 0.02222694772673518,
#  'sumarokov-tresotinius_122_4_17': 0.02226211422949219,
#  'tolstoy-zhivoy-trup_89_67_22': 0.0222650323966544,
#  'shakhovskoy-pustodomy_56_15_23': 0.0222748548125458,
#  'kokoshkin-vospitanie_44_16_28': 0.022287919359102164,
#  'ostrovsky-ne-tak-zhivi-kak-hochetsya_75_24_28': 0.02229220992044671,
#  'pisarev-poezdka-v-kronshtadt_182_8_43': 0.022301789513101668,
#  'fonvizin-brigadir_134_0_64': 0.022305753905654226,
#  'fonvizin-brigadir_134_4_14': 0.022311950509398732,
#  'ostrovsky-svoi-sobaki-gryzutsya-chuzhaya-ne-pristavaj_13_4_68': 0.02231272679287765,
#  'chekhov-leshii_71_13_18': 0.022327456947148216,
#  'mayakovsky-misteriya-buff_116_2_84': 0.022338750093181738,
#  'sumarokov-chudovischi_121_21_27': 0.02234788854945087,
#  'tolstoy-vlast-tmy_183_7_24': 0.022348201659854537,
#  'ostrovsky-puchina_50_17_24': 0.02238430494109906,
#  'mayakovsky-klop_113_1_58': 0.022395387567728867,
#  'ostrovsky-na-bojkom-meste_68_21_19': 0.02243631229039219,
#  'ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty_74_4_26': 0.022450580441317394,
#  'lomonosov-tamira-i-selim_51_19_6': 0.02247006110531084,
#  'tolstoy-vlast-tmy_183_73_14': 0.02248724138289212,
#  'knyazhnin-hvastun_180_32_11': 0.022514235830517766,
#  'sumarokov-rogonosets-po-voobrazheniju_100_33_18': 0.022528154632061675,
#  'ostrovsky-poslednyaya-zhertva_125_28_42': 0.022574732881971763,
#  'ekaterina-vtoraja-rasstroennaja-semja_82_15_5': 0.022597653585879087,
#  'gogol-zhenitba_11_28_27': 0.022603810779453247,
#  'shakhovskoy-svoya-semya_146_4_38': 0.02261052728410881,
#  'ostrovsky-pozdnyaya-lyubov_52_24_39': 0.022645645982943524,
#  ...}

# %%
parsed_text, clusters1 = cluster_text(dramas_texts[119][3], functor, clust_model_kmeans)

for person, rep in parsed_text:
    print(person)
    for phrase in rep:
        print(phrase + ': ' + colored(rep[phrase], 'red'))
    print('\n')
# Out:
# Граф
# А, здравствуйте, сударь! Я слышал, говорят, Что вы - мне странно то, но шутки тут не к месту - Хотите у меня отбить мою невесту? И место самое, которое просил, Которое умом и кровью заслужил! Что вы, что вы, сударь, в числе моих злодеев, Что ищете пожать плоды моих трофеев, Что вы, читавшие мой список послужной, Равняться вздумали заслугами со мной! Не смея отвечать...: 17
#
#
# Модестов
# Я время дожидался, Пока вы кончите! но всякий бы признался, Что вы сердиться так за это не должны, И службой нашею мы, кажется, равны.: 17
#
#
# Граф
# Как? мы равны, сударь! Вы ль это говорите? Заслуги ли свои с моими вы сравните? Я в службу налицо вступил в пятнадцать лет, Я был уж офицер, - а вы, сударь, кадет. Я всюду поспевал: был в тысяче сраженьях, В траншеях, в приступах, в победах, в пораженьях, Везде торжествовал - и в мире, и в войне; Спросите всякого: все знают обо мне! Все видели меня при тысяче осадах, Передним в приступах и задним в ретирадах! Могу ли позабыть я первый мой поход? То было в Австрии, не вспомню только год, В июле месяце, числа... числа шестого, Шестого, точно так! с поста передового Сраженье началось поутру в три часа. И тут-то в первый раз я строил чудеса! Граф Знатов в этот штурм чуть жизни не лишился! Вы знаете его? он выгодно женился. Жена его мила, в больших теперь связях, А лучше что всего - богата так, что страх! Но грех завидовать такой его удаче: Я был вчера у них, они живут на даче, Представьте...: 16
#
#
# Модестов
# Знаю всё и, право, очень рад, Что вы из Австрии приехали назад. А что до наших мест, успехи вам покажут, Что я не без друзей.: 17
#
#
# Граф
# Им наотрез откажут, И места моего, конечно, я. дождусь; Когда не верите, так я вам побожусь! Мои, сударь, друзья на ваших не похожи, И ваши - мелочь всё, а наши - так вельможи! И чтоб решительно уверить в этом вас, Так я с одним письмом отправлюся сейчас Искать протекции - она всему порука! А от кого письмо? Вот в этом-то и штука, Чтоб знать, кем действовать и успевать в делах! Особа эта здесь в больших теперь связях. Загорской друг она. Но более ни слова; Стараться за меня нет ничего дурного. Насчет протекции я здесь сильнее всех И смело, наконец, ручаюсь за успех.: 15
#
#
# Модестов
# Загорской друг? да кто ж? Ветрова?.. статься может. Она знакома мне и, верно, мне поможет. Вот случай! - И теперь успеть не мудрено - Нарочно съезжу к ней.: 0
#
#
# Граф
# Уж дело решено. Но если б даже мне, чего не может статься, Пришлося как-нибудь от места отказаться, Так всё Прелестиной не вам же обладать, И тетка может ей...: 11
#
#
# Модестов
# Любить вас приказать.: 10
#
#
# Граф
# Нельзя ли помолчать? Я говорю, конечно, И лучше и скорей...: 8
#
#
# Модестов
# И страх бесчеловечно!: 5
#
#
# Граф
# О, зависть! Но я вас смеяться отучу; Я это говорю и этим не шучу. Язык, сударь, для нас всего дороже в свете; В любви ли, в обществе ль, в ученом ли совете - Искусным языком мы делать можем всё. Коль мало этого, прибавлю вам еще, Что стыдно и смешно, и глупо для иного С терпеньем слушать вздор и не сказать ни слова!: 17
#
#
# Модестов
# Нужнее, кажется, чтоб делу пособить, Так больше хлопотать и меньше говорить: Болтанье лишнее и скучно и несносно...: 8
#
#
# Граф
# Или меня бесить хотите вы нарочно? - Вас слушать и молчать терпенья, право, нет. Меня ли вам учить? когда я был трех лет, Так я уж говорил гораздо вас бойчее, И громче, и скорей, и лучше, и вольнее! Однажды с братьями заспорил что-то я, Но это так умно, что бабушка моя, Взяв на руки меня...: 17
#
#
# Модестов
# Ну, люди уж сбежались!: 17

# %%
parsed_text, clusters1 = cluster_text(dramas_texts[65][44], functor, clust_model_kmeans)

for person, rep in parsed_text:
    print(person)
    for phrase in rep:
        print(phrase + ': ' + colored(rep[phrase], 'red'))
    print('\n')
# Out:
# Аметистов
# Бедные... Что же это Андрей Павлыч, куда он девался?  Ужо подожду здесь. Ах, девушка, девушка, милая... Вот
#               наша жизнь! Кажется, взял бы, лег да умер за нее... Кому я нужен?.. Презренный червь и больше ничего...: 10
#
#
# Людмила Григорьевна
# Эй, вы, не видали моего благоверного?..: 5
#
#
# Аметистов
# Что-с? Нет-с... Зачем ему быть здесь? Он ведь сейчас в казармах, в госпитале...: 12
#
#
# Людмила Григорьевна
# Перестаньте врать.... Тоже нашли дуру. С ваше-то могу понимать...: 8
#
#
# Аметистов
# Да вы о чем, Людмила Григорьевна.: 16
#
#
# Людмила Григорьевна
# А вот об этом. Вы все меня обманываете.  Говорите, где
#               Андрей?: 1
#
#
# Аметистов
# Андрей? Вот я что скажу вам, сударыня... Да вы присядьте, Людмила Григорьевна. Сядем
#               рядком да поговорим ладком...: 4
#
#
# Людмила Григорьевна
# Не заговаривайте зубов, пожалуйста: я не маленькая. Татьяна Васильевна здесь? О, я
#               знаю, что она здесь... У них назначено свидание. Я им покажу... .: 4
#
#
# Аметистов
# Людмила Григорьевна, голубушка, позвольте сказать всего одно словечко...: 10
#
#
# Людмила Григорьевна
# А мне наплевать на вас, на всех... Пустите!.. .: 15

# %%
import seaborn as sns

fig, ax = plt.subplots()
fig.set_size_inches(30, 20)
# plt.xlim(0.6, 1.2)
# plt.ylim(-1.6, -0.8)

authors = [drama_name.split('-')[0] for drama_name in dramas_names]

authors_sizes = {author: 20 for author in authors}
authors_sizes['lomonosov'] = 200

sns.scatterplot(x=[x for x, y in drama2vec],
                y=[y for x, y in drama2vec],
                hue=authors,
                size=authors,
                sizes=authors_sizes,
               )

plt.grid()
